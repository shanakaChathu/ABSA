# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('stopwords')

import pandas as pd 
import numpy as np 
from nltk.tokenize import word_tokenize
import re
from nltk.corpus import wordnet
import pandas as pd 
import numpy as np 
from nltk.tokenize import word_tokenize
import re
from sklearn.base import BaseEstimator, TransformerMixin
from nltk.corpus import wordnet
import pandas as pd 
import numpy as np 
import string
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('treebank')
from nltk.tag import UnigramTagger
from nltk.corpus import treebank
import pandas as pd 
import numpy as np 
import string
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec
#import fasttext
import gensim
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
import seaborn as sns 
import re  # For preprocessing
from time import time  # To time our operations
from collections import defaultdict  # For word frequency
import spacy  # For preprocessing
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt 
from xlwt import Workbook 
import wordcloud
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.naive_bayes import MultinomialNB
#from xgboost import XGBClassifier
#import xgboost
import scipy.sparse


import time
import warnings

#settings
start_time=time.time()
color = sns.color_palette()
sns.set_style("dark")
eng_stopwords = set(stopwords.words("english"))
warnings.filterwarnings("ignore")

from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 

from sklearn.model_selection import cross_validate
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import os
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
from scipy import interp
from itertools import cycle
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import nltk
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import warnings
import multiprocessing
from gensim.models import Word2Vec
#from gensim.models import FastText
from sklearn.metrics import roc_auc_score
from numpy import asarray

from sklearn.model_selection import cross_validate
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import os
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
from scipy import interp
from itertools import cycle
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import nltk
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import warnings
import multiprocessing
from gensim.models import Word2Vec
#from gensim.models import FastText
from sklearn.metrics import roc_auc_score

from keras.models import Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation
from keras.layers import BatchNormalization
from keras.models import model_from_json
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.layers import BatchNormalization
from keras import backend as K
from sklearn.metrics import recall_score
from keras.models import load_model
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
import matplotlib.pyplot as pyplot

from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers.convolutional import Conv1D
from keras.layers import GlobalMaxPooling1D


from keras.models import Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation
from keras.layers import BatchNormalization
from keras.models import model_from_json
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.layers import BatchNormalization
from keras import backend as K
from sklearn.metrics import recall_score
from keras.models import load_model
import tensorflow as tf 
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from numpy import array
from numpy import asarray
from numpy import zeros
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.

# %%
mainloc='/content/drive/My Drive/Research/ABSA_Final/'
mainloc
# Out:
# '/content/drive/My Drive/Research/ABSA_Final/'

# %%
df=pd.read_csv(mainloc+"df_train.csv")
df=df[~df['cleanAnswer'].isna()]
print("Size of training dataset: ",df.shape)
# Out:
# Size of training dataset:  (10058, 15)

# %%
df=pd.read_csv(mainloc+"df_train.csv")
df=df[~df['cleanAnswer'].isna()]
print("Size of training dataset: ",df.shape)

df_we=pd.read_csv(mainloc+"Data/data_clean_full_corpus.csv")
df_we=df_we[~df_we['cleanAnswer'].isna()]
print("Size of word embedding dataset: ",df_we.shape)

sent=df[['comment','cleanAnswer','cleanAnswer1','sentiment']]
sent.head(2)
# Out:
# Size of training dataset:  (10058, 15)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-61c7bfc970a1> in <module>()
#       3 print("Size of training dataset: ",df.shape)
#       4
# ----> 5 df_we=pd.read_csv(mainloc+"Data/data_clean_full_corpus.csv")
#       6 df_we=df_we[~df_we['cleanAnswer'].isna()]
#       7 print("Size of word embedding dataset: ",df_we.shape)
#
# ...

# %%
df=df.reset_index()

# %% [markdown]
# # Basic Models with Basic Features

# %%
#Functions 

def splitdata(df, feat,target,splitratio,valflag):
    x = df[feat]
    y = df[target]
    x_train_main, x_test, y_train_main, y_test = train_test_split(x, y, test_size=splitratio, random_state=100, stratify=y)
    x_train, x_val, y_train, y_val = train_test_split(x_train_main, y_train_main, test_size=splitratio, random_state=100, 
                                                      stratify=y_train_main)
    encoder = preprocessing.LabelEncoder()
    y_train_main = encoder.fit_transform(y_train_main)
    y_train = encoder.fit_transform(y_train)
    y_val = encoder.fit_transform(y_val)
    y_test = encoder.fit_transform(y_test)
    
    y_train_main_c = label_binarize(y_train_main, classes=[0,1,2])
    y_train_c = label_binarize(y_train, classes=[0,1,2])
    y_val_c = label_binarize(y_val, classes=[0,1,2])
    y_test_c = label_binarize(y_test, classes=[0,1,2])
    
    if(valflag):
        return x, y, x_train,x_val,x_test,y_train,y_val, y_test,y_train_c,y_val_c,y_test_c 
    else:
        return x, y, x_train_main,x_test,y_train_main, y_test, y_train_main_c,y_test_c
    
def splitdata_we(x,y,splitratio,valflag):
    x_train_main, x_test, y_train_main, y_test = train_test_split(x, y, test_size=splitratio, random_state=10, stratify=y)
    x_train, x_val, y_train, y_val = train_test_split(x_train_main, y_train_main, test_size=splitratio, random_state=10, 
                                                      stratify=y_train_main)
    encoder = preprocessing.LabelEncoder()
    y_train_main = encoder.fit_transform(y_train_main)
    y_train = encoder.fit_transform(y_train)
    y_val = encoder.fit_transform(y_val)
    y_test = encoder.fit_transform(y_test)
    
    y_train_main_c = label_binarize(y_train_main, classes=[0,1,2])
    y_train_c = label_binarize(y_train, classes=[0,1,2])
    y_val_c = label_binarize(y_val, classes=[0,1,2])
    y_test_c = label_binarize(y_test, classes=[0,1,2])
    
    if(valflag):
        return x, y, x_train,x_val,x_test,y_train,y_val, y_test,y_train_c,y_val_c,y_test_c 
    else:
        return x, y, x_train_main,x_test,y_train_main, y_test, y_train_main_c,y_test_c

def accuracymeasures(y_test,y_test_c, predictions):
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions, average='weighted')
    recall = recall_score(y_test, predictions, average='weighted')
    f1score = f1_score(y_test, predictions, average='weighted')
    target_names = ['Neutral', 'Negative', 'Positive']
    print("Classification report")
    print("---------------------","\n")
    print(classification_report(y_test, predictions,target_names=target_names),"\n")
    print("Confusion Matrix")
    print("---------------------","\n")
    print(confusion_matrix(y_test, predictions),"\n")

    print("Accuracy Measures")
    print("---------------------","\n")
    print("Accuracy: ", accuracy)
    print("Precision: ", precision)
    print("Recall: ", recall)
    print("F1 Score: ", f1score)
        
def train_model(classifier, feature_vector_train, label):
    classifier.fit(feature_vector_train, label)
    return classifier
        
def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    predictions_prob = clf.predict_proba(feature_vector_valid)
    return predictions, predictions_prob

def multiclassroc(y_test,prediction_prob):
    fpr = {}
    tpr = {}
    thresh ={}
    
    n_class = 3
    for i in range(n_class):    
        fpr[i], tpr[i], thresh[i] = roc_curve(y_test, prediction_prob[:,i], pos_label=i)
        
    plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Passive vs Rest')
    plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Neutral vs Rest')
    plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Positive vs Rest')
    plt.title('Multiclass ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive rate')
    plt.legend(loc='best')
    #plt.savefig('Multiclass ROC',dpi=300)
    
def precrecallcurve(y_test_c, prediction_prob):
    precision = dict()
    recall = dict()
    for i in range(3):
        precision[i], recall[i], _ = precision_recall_curve(y_test_c[:, i],prediction_prob[:, i])
        plt.plot(recall[i], precision[i], lw=2, label='class {}'.format(i))
    
    plt.xlabel("recall")
    plt.ylabel("precision")
    plt.legend(loc="best")
    plt.title("precision vs. recall curve")
    plt.show()
    
#Word embeddings 

def create_txt(df,var):
    text=[]
    for i in df[var]:
        li = list(i.split())
        text.append(li)
    return text
        
def word2vec(text,min_count,size,workers,window,sg):
    model = Word2Vec(text,min_count=min_count,size=size,workers=workers,window=window,sg=sg)
    return model 

def make_feature_vec(words, model, num_features):
    """
    Average the word vectors for a set of words
    """
    feature_vec = np.zeros((num_features,),dtype="float32")  # pre-initialize (for speed)
    nwords = 0
    index2word_set = set(model.wv.index2word)  # words known to the model
   

    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1
            feature_vec = np.add(feature_vec,model[word])
    
    feature_vec = np.divide(feature_vec, nwords)
    return feature_vec

def get_avg_feature_vecs(reviews, model, num_features):
    """
    Calculate average feature vectors for all reviews
    """
    counter = 0
    review_feature_vecs = np.zeros((len(reviews),num_features), dtype='float32')  # pre-initialize (for speed)
    
    for review in reviews:
        review_feature_vecs[counter] = make_feature_vec(review, model, num_features)
        counter = counter + 1
    return review_feature_vecs

def word_embed(df,df_we,num_features,wetype,window,sg):
    text_we=create_txt(df_we,'cleanAnswer')
    text_model=create_txt(df,'cleanAnswer')
    
    if(wetype=='w2vec'):
        model=word2vec(text_we,1,num_features,7,window,sg)
        
    if(wetype=='ft'):
        model = FastText(text_we,size=num_features,window=window,sg=sg,iter=100)

    x=get_avg_feature_vecs(text_model,model, num_features)
    return x 
    
def recall_m(y_true,y_pred):
    import tensorflow as tf
    #recall=recall_score(y_true.t.math.argmax(axis=1), y_pred.K.math.argmax(axis=1), average='macro')
    a=tf.math.argmax(y_true,axis=1)
    b=tf.math.argmax(y_pred,axis=1)
    recall=recall_score(a,b,average='macro')
    return reccall 
    
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

def emb_dictionary(filename):
    embedding_dictionary = dict()
    f = open(filename)
    for line in f:
        values = line.split()
        word = values[0]
        coefs = asarray(values[1:], dtype='float32')
        embedding_dictionary[word] = coefs
    f.close()
    return embedding_dictionary

def emb_matrix(embeddings_dictionary,we_size):
    embedding_matrix = zeros((vocab_length, we_size))
    for word, index in word_tokenizer.word_index.items():
        embedding_vector = embeddings_dictionary.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector
    return  embedding_matrix

def pred_neural(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid).argmax(axis=1)
    predictions_prob = clf.predict(feature_vector_valid)
    return predictions, predictions_prob
    
def accuracy_neural(y_val,y_pred,target_names):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))

def accuracy_scores_neural(model,x_train,y_train,y_train_c,x_test,y_test,y_test_c,target_names):
    print("Basic model evaluation: ")
    print("--------------------------------------------")
    loss_train,acc_train,f1_train,pre_train,rec_train = model.evaluate(x_train, y_train_c, verbose=0)
    loss_test,acc_test,f1_test,pre_test,rec_test = model.evaluate(x_test, y_test_c, verbose=0)

    print("Loss==>",'Train: %.3f, Test: %.3f' % (loss_train,loss_test))
    print("Accuracy==>",'Train: %.3f, Test: %.3f' % (acc_train,acc_test))
    print("F1==>",'Train: %.3f, Test: %.3f' % (f1_train,f1_test))
    print("Precision==>",'Train: %.3f, Test: %.3f' % (pre_train,pre_test))
    print("Recall==>",'Train: %.3f, Test: %.3f' % (rec_train,rec_test))

    print("Accuracy of Neural Network Model")
    print("--------------------------------------------")

    print("\nTraining accuracy")
    print("--------------------------------------------")
    predictions, predictions_prob  = pred_neural(model,x_train)
    accuracy_neural(y_train,predictions,target_names)

    print("\n Testing accuracy")
    print("--------------------------------------------")
    predictions, predictions_prob  = pred_neural(model,x_test)
    accuracy_neural(y_test,predictions,target_names)
    
         
def accuracy_curve(history,measure,title):
    print(title)
    pyplot.plot(history.history[measure], label='train')
    pyplot.plot(history.history['val_'+measure], label='val')
    pyplot.title(title)
    pyplot.legend()
    pyplot.show()

# %% [markdown]
# # Logistic regression model

# %%
#Feature-Count
#model: logistic

x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(df, 'cleanAnswer','sentiment', 0.3,False)

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

model = linear_model.LogisticRegression(class_weight="balanced")
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.71      0.81      0.75       985
#     Negative       0.89      0.83      0.86      1946
#     Positive       0.48      0.46      0.47        87
#
#     accuracy                           0.81      3018
#    macro avg       0.69      0.70      0.69      3018
# weighted avg       0.82      0.81      0.81      3018
#
#
# Confusion Matrix
# ---------------------
#
# [[ 797  170   18]
#  [ 305 1615   26]
#  [  25   22   40]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.8124585818422797
# Precision:  0.8208213237355156
# Recall:  0.8124585818422797
# F1 Score:  0.8147549353738752

# %%
#Feature: tfidf
#model: logistic

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)

vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1, 1), max_features=4000)
vect.fit(x)

model = linear_model.LogisticRegression(class_weight="balanced")
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)

predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.70      0.81      0.75       985
#     Negative       0.90      0.82      0.86      1946
#     Positive       0.43      0.56      0.49        87
#
#     accuracy                           0.81      3018
#    macro avg       0.68      0.73      0.70      3018
# weighted avg       0.82      0.81      0.81      3018
#
#
# Confusion Matrix
# ---------------------
#
# [[ 795  159   31]
#  [ 319 1592   35]
#  [  23   15   49]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.8071570576540755
# Precision:  0.8217544358855522
# Recall:  0.8071570576540755
# F1 Score:  0.8116169382230184

# %%
precrecallcurve(y_test_c, prediction_prob)

# %% [markdown]
# # Random forest model

# %%
#Features: count 
#Model: Random forest

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)

# Feature2-tfidf
vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

model = RandomForestClassifier(class_weight="balanced")
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.74      0.75      0.74       985
#     Negative       0.86      0.88      0.87      1946
#     Positive       0.82      0.10      0.18        87
#
#     accuracy                           0.82      3018
#    macro avg       0.81      0.58      0.60      3018
# weighted avg       0.82      0.82      0.81      3018
#
#
# Confusion Matrix
# ---------------------
#
# [[ 741  243    1]
#  [ 224 1721    1]
#  [  40   38    9]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.818754141815772
# Precision:  0.8185207718307626
# Recall:  0.818754141815772
# F1 Score:  0.8105106057448972

# %%
#Features: count 
#Model: Random forest
#uncleaned

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(df, 'comment','sentiment', 0.3,False)

# Feature2-tfidf
vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

model = RandomForestClassifier(class_weight="balanced")
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.73      0.76      0.75       985
#     Negative       0.86      0.88      0.87      1946
#     Positive       1.00      0.03      0.07        87
#
#     accuracy                           0.82      3018
#    macro avg       0.86      0.56      0.56      3018
# weighted avg       0.82      0.82      0.81      3018
#
#
# Confusion Matrix
# ---------------------
#
# [[ 747  238    0]
#  [ 229 1717    0]
#  [  43   41    3]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.817428760768721
# Precision:  0.8227516707205489
# Recall:  0.817428760768721
# F1 Score:  0.8069410411434527

# %%
#Features: tfidf
#Model: Random forest

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)


# Feature2-tfidf
vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1, 1), max_features=50000)
vect.fit(x)

model = RandomForestClassifier(class_weight="balanced")
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.76      0.62      0.68       665
#     Negative       0.84      0.94      0.89      1636
#     Positive       0.00      0.00      0.00        58
#
#     accuracy                           0.82      2359
#    macro avg       0.53      0.52      0.52      2359
# weighted avg       0.80      0.82      0.81      2359
#
#
# Confusion Matrix
# ---------------------
#
# [[ 415  250    0]
#  [ 106 1530    0]
#  [  26   32    0]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.824501907587961
# Precision:  0.7994554508477945
# Recall:  0.824501907587961
# F1 Score:  0.8085234602090798

# %% [markdown]
# # SVM Model

# %%
#Features: count
#Model: SVM 

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

model =SVC(kernel='rbf',class_weight='balanced',probability=True)
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.68      0.82      0.74       985
#     Negative       0.88      0.82      0.85      1946
#     Positive       0.70      0.26      0.38        87
#
#     accuracy                           0.80      3018
#    macro avg       0.75      0.63      0.66      3018
# weighted avg       0.81      0.80      0.80      3018
#
#
# Confusion Matrix
# ---------------------
#
# [[ 803  179    3]
#  [ 345 1594    7]
#  [  33   31   23]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.8018555334658715
# Precision:  0.8117427790057015
# Recall:  0.8018555334658715
# F1 Score:  0.8012082483247636

# %%
#Features: tfidf
#Model: SVM 

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)

# Feature2-tfidf
vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1, 1), max_features=50000)
vect.fit(x)

model =SVC(kernel='rbf',class_weight='balanced',probability=True)
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.68      0.77      0.72       665
#     Negative       0.89      0.87      0.88      1636
#     Positive       1.00      0.03      0.07        58
#
#     accuracy                           0.82      2359
#    macro avg       0.86      0.56      0.56      2359
# weighted avg       0.83      0.82      0.81      2359
#
#
# Confusion Matrix
# ---------------------
#
# [[ 511  154    0]
#  [ 213 1423    0]
#  [  31   25    2]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.8206867316659602
# Precision:  0.8314061430550201
# Recall:  0.8206867316659602
# F1 Score:  0.8140827817684665

# %% [markdown]
# # Light GBM model

# %%
#feature:count
#model: lightgbm

# Splitting the file
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

xtrain_vect= vect.transform(x_train).astype('float32')
xtest_vect = vect.transform(x_test).astype('float32')
y_train=y_train.astype('float32')
y_test=y_test.astype('float32')

fit_params = {#'early_stopping_rounds': 10, 
              'eval_metric' : 'auc_mu', 
              'eval_set' : [(xtrain_vect,y_train)],
              'eval_names': ['train','valid'],
              'verbose': 10,
              'feature_name': 'auto', 
             }

model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', objective='multiclass', random_state=1)
model.fit(xtrain_vect, y_train, **fit_params)
predictions,prediction_prob=pred(model,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# [10]	train's auc_mu: 0.941929	train's multi_logloss: 0.67082
# [20]	train's auc_mu: 0.960233	train's multi_logloss: 0.512139
# [30]	train's auc_mu: 0.970141	train's multi_logloss: 0.426652
# [40]	train's auc_mu: 0.976315	train's multi_logloss: 0.370582
# [50]	train's auc_mu: 0.980497	train's multi_logloss: 0.329148
# [60]	train's auc_mu: 0.983252	train's multi_logloss: 0.298594
# [70]	train's auc_mu: 0.98555	train's multi_logloss: 0.273816
# [80]	train's auc_mu: 0.9874	train's multi_logloss: 0.253562
# [90]	train's auc_mu: 0.988865	train's multi_logloss: 0.235927
# [100]	train's auc_mu: 0.990076	train's multi_logloss: 0.220655
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.63      0.78      0.70       665
#     Negative       0.91      0.81      0.86      1636
#     Positive       0.29      0.33      0.31        58
#
#     accuracy                           0.79      2359
# ...

# %%
#feature:tfidf
#model: lightgbm

# Splitting the file
x, y, x_train,x_val,x_test,y_train,y_val, y_test,y_train_c,y_val_c,y_test_c=splitdata(sent, 'cleanAnswer','sentiment', 0.3,True)

vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=50000)
vect.fit(x)

xtrain_vect= vect.transform(x_train).astype('float32')
xval_vect= vect.transform(x_val).astype('float32')
xtest_vect = vect.transform(x_test).astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

fit_params = {'early_stopping_rounds': 1000, 
              'eval_metric' : 'auc_mu', 
              'eval_set' : [(xtrain_vect,y_train),(xval_vect, y_val)],
              'eval_names': ['train','valid'],
              'verbose': 10,
              'feature_name': 'auto', 
             }


model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', 
                              objective='multiclass', random_state=1,reg_alpha=0.3,reg_lambda=0.3,n_estimators=10000)

model.fit(xtrain_vect, y_train, **fit_params)

print("\n","*******Training accuracy scores*******")
print("--------------------------------------------","\n")
predictions,prediction_prob=pred(model,xtrain_vect)
accuracymeasures(y_train,y_train_c, predictions)

print("\n","*******Validation accuracy scores*******")
print("----------------------------------------------","\n")
predictions,prediction_prob=pred(model,xval_vect)
accuracymeasures(y_val,y_val_c, predictions)

print("\n","*******Testing accuracy scores*******")
print("--------------------------------------------","\n")
predictions,prediction_prob=pred(model,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)


multiclassroc(y_test,prediction_prob)
lgb.plot_metric(model)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Training until validation scores don't improve for 1000 rounds
# [10]	train's auc_mu: 0.955812	train's multi_logloss: 0.60826	valid's auc_mu: 0.797111	valid's multi_logloss: 0.740055
# [20]	train's auc_mu: 0.970767	train's multi_logloss: 0.443454	valid's auc_mu: 0.824574	valid's multi_logloss: 0.624297
# [30]	train's auc_mu: 0.979337	train's multi_logloss: 0.354439	valid's auc_mu: 0.832722	valid's multi_logloss: 0.566758
# [40]	train's auc_mu: 0.984329	train's multi_logloss: 0.298551	valid's auc_mu: 0.831825	valid's multi_logloss: 0.538314
# [50]	train's auc_mu: 0.987793	train's multi_logloss: 0.258568	valid's auc_mu: 0.835081	valid's multi_logloss: 0.521205
# [60]	train's auc_mu: 0.990285	train's multi_logloss: 0.228782	valid's auc_mu: 0.834528	valid's multi_logloss: 0.511972
# [70]	train's auc_mu: 0.992224	train's multi_logloss: 0.205681	valid's auc_mu: 0.83159	valid's multi_logloss: 0.508108
# ...

# %%
#feature:tfidf,countvect, ngram:1,2,3
#model: lightgbm

# Splitting the file
x, y, x_train,x_val,x_test,y_train,y_val, y_test,y_train_c,y_val_c,y_test_c=splitdata(sent, 'cleanAnswer','sentiment', 0.3,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtrain_vect_count12= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtrain_vect_count13= count_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf= tfidf_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf12= tfidf_vect.transform(x_train).astype('float32')

#Testing 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtest_vect_count12= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtest_vect_count13= count_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf= tfidf_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf12= tfidf_vect.transform(x_test).astype('float32')


#validation

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xval_vect_count12= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xval_vect_count13= count_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf= tfidf_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf12= tfidf_vect.transform(x_val).astype('float32')

xtrain_vect=scipy.sparse.hstack([xtrain_vect_count, xtrain_vect_tfidf,xtrain_vect_tfidf12,xtrain_vect_count12,xtrain_vect_count13])
xval_vect=scipy.sparse.hstack([xval_vect_count, xval_vect_tfidf,xval_vect_tfidf12,xval_vect_count12,xval_vect_count13])
xtest_vect=scipy.sparse.hstack([xtest_vect_count, xtest_vect_tfidf,xtest_vect_tfidf12,xtest_vect_count12,xtest_vect_count13])
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

fit_params = {'early_stopping_rounds': 10, 
              'eval_metric' : 'auc_mu', 
              'eval_set' : [(xtrain_vect, y_train),(xval_vect, y_val)],
              'eval_names': ['train','valid'],
              'verbose': 10,
              'feature_name': 'auto', 
             }

model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', 
                              objective='multiclass', random_state=1,reg_alpha=0.3,reg_lambda=0.3,n_estimators=1000)

model.fit(xtrain_vect, y_train, **fit_params)

print("\n","*******Training accuracy scores*******")
print("--------------------------------------------","\n")
predictions,prediction_prob=pred(model,xtrain_vect)
accuracymeasures(y_train,y_train_c, predictions)

print("\n","*******Validation accuracy scores*******")
print("----------------------------------------------","\n")
predictions,prediction_prob=pred(model,xval_vect)
accuracymeasures(y_val,y_val_c, predictions)

print("\n","*******Testing accuracy scores*******")
print("--------------------------------------------","\n")
predictions,prediction_prob=pred(model,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)

multiclassroc(y_test,prediction_prob)
lgb.plot_metric(model)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Training until validation scores don't improve for 10 rounds
# [10]	train's auc_mu: 0.958863	train's multi_logloss: 0.58457	valid's auc_mu: 0.83145	valid's multi_logloss: 0.718403
# [20]	train's auc_mu: 0.971832	train's multi_logloss: 0.422161	valid's auc_mu: 0.840657	valid's multi_logloss: 0.608763
# Early stopping, best iteration is:
# [19]	train's auc_mu: 0.970711	train's multi_logloss: 0.432902	valid's auc_mu: 0.841825	valid's multi_logloss: 0.614464
#
#  *******Training accuracy scores*******
# --------------------------------------------
#
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.64      0.84      0.73      1086
#     Negative       0.94      0.79      0.86      2671
#     Positive       0.47      0.99      0.63        94
#
#     accuracy                           0.81      3851
#    macro avg       0.68      0.87      0.74      3851
# weighted avg       0.85      0.81      0.81      3851
# ...

# %% [markdown]
# # Naive Bayes Model

# %%
#Feature: count
#model: Naive bayes
from sklearn.naive_bayes import GaussianNB
x,y,x_train,x_test,y_train, y_test,y_train_c,y_test_c = splitdata(sent, 'cleanAnswer','sentiment', 0.3,False)

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

model = MultinomialNB()
xtrain_vect= vect.transform(x_train)
xtest_vect = vect.transform(x_test)
clf = train_model(model, xtrain_vect, y_train)
predictions,prediction_prob=pred(clf,xtest_vect)
accuracymeasures(y_test,y_test_c, predictions)
multiclassroc(y_test,prediction_prob)
#precrecallcurve(y_test_c, prediction_prob)
# Out:
# Classification report
# ---------------------
#
#               precision    recall  f1-score   support
#
#      Neutral       0.78      0.51      0.62       665
#     Negative       0.82      0.95      0.88      1636
#     Positive       0.22      0.07      0.11        58
#
#     accuracy                           0.81      2359
#    macro avg       0.61      0.51      0.53      2359
# weighted avg       0.79      0.81      0.79      2359
#
#
# Confusion Matrix
# ---------------------
#
# [[ 340  313   12]
#  [  78 1556    2]
#  [  17   37    4]]
#
# Accuracy Measures
# ---------------------
#
# Accuracy:  0.8054260279779568
# Precision:  0.7919623894252152
# Recall:  0.8054260279779568
# F1 Score:  0.7861743187730714

# %% [markdown]
# # Basic Models with word Embedding features

# %%
#Create cbow word embedding and convert ito doc2vec 
x_cbow=word_embed(df,df_we,300,'w2vec',10,1)
# Out:
# INFO - 00:33:34: collecting all words and their counts
# INFO - 00:33:34: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 00:33:34: PROGRESS: at sentence #10000, processed 77408 words, keeping 11801 word types
# INFO - 00:33:34: PROGRESS: at sentence #20000, processed 138248 words, keeping 18228 word types
# INFO - 00:33:34: PROGRESS: at sentence #30000, processed 209359 words, keeping 24148 word types
# INFO - 00:33:34: PROGRESS: at sentence #40000, processed 258862 words, keeping 29043 word types
# INFO - 00:33:34: PROGRESS: at sentence #50000, processed 315969 words, keeping 36006 word types
# INFO - 00:33:34: PROGRESS: at sentence #60000, processed 386896 words, keeping 42598 word types
# INFO - 00:33:34: PROGRESS: at sentence #70000, processed 452777 words, keeping 48641 word types
# INFO - 00:33:34: PROGRESS: at sentence #80000, processed 507520 words, keeping 54924 word types
# ...

# %%
#Feature_word embedding 
#Model:lightgbm
#Here training and testing sets wre used 

x=x_cbow
y = df['sentiment']
        
x, y, x_train,x_val,x_test,y_train,y_val, y_test,y_train_c,y_val_c,y_test_c=splitdata_we(x,y,0.2,True)
                                                                                    
x_train=x_train.astype('float32')
x_val=x_val.astype('float32')
x_test=x_test.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

fit_params = {'early_stopping_rounds': 20, 
              'eval_metric' : 'auc_mu', 
              'eval_set' : [(x_train,y_train),(x_val,y_val)],
              'eval_names': ['train','valid'],
              'verbose': 10,
              'feature_name': 'auto', 
             }

model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', objective='multiclass', random_state=1,
                          reg_alpha=0.7,reg_lambda=0.7,n_estimators=100,max_depth=3)
model.fit(x_train, y_train, **fit_params)

print("\n","*******Training accuracy scores*******")
print("--------------------------------------------","\n")
predictions,prediction_prob=pred(model,x_train)
accuracymeasures(y_train,y_train_c, predictions)
auc= roc_auc_score(y_train, prediction_prob, multi_class='ovr')
print("auc: ", auc)

print("\n","*******Validation accuracy scores*******")
print("----------------------------------------------","\n")
predictions,prediction_prob=pred(model,x_val)
accuracymeasures(y_val,y_val_c, predictions)
auc= roc_auc_score(y_val, prediction_prob, multi_class='ovr')
print("auc: ", auc)

print("\n","*******Testing accuracy scores*******")
print("--------------------------------------------","\n")
predictions,prediction_prob=pred(model,x_test)
accuracymeasures(y_test,y_test_c, predictions)
auc= roc_auc_score(y_test, prediction_prob, multi_class='ovr')
print("auc: ", auc)
# Out:
# Training until validation scores don't improve for 20 rounds
# [10]	train's auc_mu: 0.948701	train's multi_logloss: 0.67944	valid's auc_mu: 0.872358	valid's multi_logloss: 0.756932
# [20]	train's auc_mu: 0.963148	train's multi_logloss: 0.523466	valid's auc_mu: 0.88514	valid's multi_logloss: 0.639868
# [30]	train's auc_mu: 0.97114	train's multi_logloss: 0.439846	valid's auc_mu: 0.894185	valid's multi_logloss: 0.581824
# [40]	train's auc_mu: 0.976593	train's multi_logloss: 0.382553	valid's auc_mu: 0.901632	valid's multi_logloss: 0.544682
# [50]	train's auc_mu: 0.980144	train's multi_logloss: 0.344489	valid's auc_mu: 0.903009	valid's multi_logloss: 0.52356
# [60]	train's auc_mu: 0.982957	train's multi_logloss: 0.314161	valid's auc_mu: 0.904159	valid's multi_logloss: 0.508367
# [70]	train's auc_mu: 0.985151	train's multi_logloss: 0.288558	valid's auc_mu: 0.906566	valid's multi_logloss: 0.496392
# ...

# %% [markdown]
# # Neural Network based models with Word embeddings

# %%
#Neural network model with word embedding ( Pre-trained word embedddings using cbow method)

x=df['cleanAnswer']
y=df['sentiment']

word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(x)
vocab_length = len(word_tokenizer.word_index) + 1
embedded_sentences = word_tokenizer.texts_to_sequences(x)

word_count = lambda sentence: len(word_tokenize(sentence))
longest_sentence = max(x, key=word_count)
length_long_sentence = len(word_tokenize(longest_sentence))
padded_sentences = pad_sequences(embedded_sentences, length_long_sentence, padding='post')

embeddings_dictionary=emb_dictionary('word_embeddings/w2v_cbow.txt')
embedding_matrix=emb_matrix(embeddings_dictionary,300)

x, y, x_train,x_test,y_train,y_test,y_train_c,y_test_c = splitdata_we(padded_sentences,y,0.2,False)

model = Sequential()
embedding_layer = Embedding(vocab_length, 300,weights=[embedding_matrix],
                            input_length=length_long_sentence, trainable=False)
model.add(embedding_layer)
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(3, activation='softmax'))
    
# compile the keras model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m,recall_m])
print(model.summary())
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience= 10)

history = model.fit(x_train, y_train_c,validation_split=0.2,callbacks=[mc,es],
                      epochs=100,batch_size=32,shuffle=True,class_weight='balanced')
#Load saved model 
dependencies = {
    'recall_m': recall_m,
    'f1_m':f1_m,
    'precision_m':precision_m
    
}

model = load_model('best_model.h5',custom_objects=dependencies)
accuracy_scores_neural(model,x_train,y_train,y_train_c,x_test,y_test,y_test_c,['Neutral', 'Negative', 'Positive'])
accuracy_curve(history,'loss','loss')
accuracy_curve(history,'accuracy','accuracy')
accuracy_curve(history,'f1_m','F1')
accuracy_curve(history,'precision_m','Precision')
accuracy_curve(history,'recall_m','Recall')
# Out:
# Basic model evaluation:
# --------------------------------------------
# Loss==> Train: 0.313, Test: 0.389
# Accuracy==> Train: 0.879, Test: 0.844
# F1==> Train: 0.877, Test: 0.843
# Precision==> Train: 0.886, Test: 0.854
# Recall==> Train: 0.868, Test: 0.833
# Accuracy of Neural Network Model
# --------------------------------------------
#
# Training accuracy
# --------------------------------------------
# Accuracy Score:  0.8786577608142494
# Precision:  0.8786577608142494
# Recall:  0.8786577608142494
# F1 score:  0.8786577608142494
#
# Classification report
# ---------------------
#               precision    recall  f1-score   support
#
#      Neutral       0.89      0.70      0.78      1773
#     Negative       0.88      0.97      0.92      4361
#     Positive       0.70      0.33      0.45       154
#
#     accuracy                           0.88      6288
#    macro avg       0.82      0.67      0.72      6288
# weighted avg       0.88      0.88      0.87      6288
#
#
# ...

# %%
#Cross validation based methods

# %%
#Logistic regression model

# %%
x = df['cleanAnswer']
y = df['sentiment']

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
x_vect_count= count_vect.transform(x).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
x_vect_count12= count_vect.transform(x).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
x_vect_count13= count_vect.transform(x).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
x_vect_tfidf= tfidf_vect.transform(x).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
x_vect_tfidf12= tfidf_vect.transform(x).astype('float32')


x_vect=scipy.sparse.hstack([x_vect_count, x_vect_tfidf,x_vect_tfidf12,x_vect_count12,x_vect_count13])

# %%
#Logistic regression model

# %%
n_folds=3

def train_model(classifier, feature_vector_train, label):
    classifier.fit(feature_vector_train, label)
    return classifier

def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    predictions_prob = clf.predict_proba(feature_vector_valid)
    return predictions, predictions_prob

def crossval(x,y,modelname,vect,average):
    acc_per_fold = []
    f1_per_fold=[]
    precision_per_fold = []
    recall_per_fold = []

    skf = StratifiedKFold(n_splits=n_folds,random_state=None, shuffle=False)
    fold_no = 1
    
    for train_index, test_index in skf.split(x, y):
      if (modelname=='logistic'):
        model = linear_model.LogisticRegression(class_weight="balanced")
      elif (modelname=='rf'):
        model = RandomForestClassifier(class_weight="balanced")
      elif (modelname=='svm'):
        model =SVC(kernel='rbf',class_weight='balanced',probability=True)
      elif (modelname=='xgb'):
        #model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', objective='multiclass', random_state=1)
        model=GradientBoostingClassifier(n_estimators=10, learning_rate=1.0,max_depth=5, random_state=0)
      elif(modelname=='nb'):
        model = MultinomialNB()

      xtrain_vect= vect.transform(x[train_index])
      xtest_vect = vect.transform(x[test_index])
      ytrain=y[train_index]
      ytest=y[test_index]
      clf = train_model(model, xtrain_vect, ytrain)
      predictions,prediction_prob=pred(clf,xtest_vect)

      accuracy = accuracy_score(ytest, predictions)
      precision = precision_score(ytest, predictions, average=average)
      recall = recall_score(ytest, predictions, average=average)
      f1score = f1_score(ytest, predictions, average=average)

      acc_per_fold.append(accuracy)
      precision_per_fold.append(precision)
      recall_per_fold.append(recall)
      f1_per_fold.append(f1score)
      
      fold_no = fold_no + 1
    return acc_per_fold,precision_per_fold,recall_per_fold,f1_per_fold

def accuracy_crossval(acc_per_fold,f1_per_fold,precision_per_fold,recall_per_fold,modelname):
    print('----------------------------------------')
    print('Score per fold - ',modelname)
    for i in range(0, len(acc_per_fold)):
        print('----------------------------------------')
        #print(f'> Fold {i+1} - Accuracy: {acc_per_fold[i]} - Precision: {precision_per_fold[i]} - Recall: {recall_per_fold[i]} - F1: {f1_per_fold[i]}')
        print(f'> Fold {i+1}')
        print('Accuracy: ',acc_per_fold[i])
        print('Precision: ',precision_per_fold[i])
        print('Recall: ',recall_per_fold[i])
        print('F1: ',f1_per_fold[i])
    print('----------------------------------------')
    print('Average scores for all folds:')
    
    print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
    print(f'> Precision: {np.mean(precision_per_fold)}')
    print(f'> Recall: {np.mean(recall_per_fold)}')
    print(f'> F1: {np.mean(f1_per_fold)}')

# %%
#df=df.reset_index()
x=df['cleanAnswer']
y=df['sentiment']

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

acc_per_fold,precision_per_fold,recall_per_fold,f1_per_fold=crossval(x,y,'logistic',vect,'weighted')
accuracy_crossval(acc_per_fold,f1_per_fold,precision_per_fold,recall_per_fold,'Logistic Regression Model')
# Out:
# ----------------------------------------
# Score per fold -  Logistic Regression Model
# ----------------------------------------
# > Fold 1
# Accuracy:  0.8320906650760513
# Precision:  0.8369076146460099
# Recall:  0.8320906650760513
# F1:  0.8235287535346484
# ----------------------------------------
# > Fold 2
# Accuracy:  0.8073367133909931
# Precision:  0.8112900392218758
# Recall:  0.8073367133909931
# F1:  0.8080512575601921
# ----------------------------------------
# > Fold 3
# Accuracy:  0.704653937947494
# Precision:  0.8104657376408962
# Recall:  0.704653937947494
# F1:  0.7105218951757306
# ----------------------------------------
# Average scores for all folds:
# > Accuracy: 0.7813604388048461 (+- 0.05517309118486883)
# > Precision: 0.8195544638362606
# > Recall: 0.7813604388048461
# > F1: 0.7807006354235236

# %%
#df=df.reset_index()
x=df['cleanAnswer']
y=df['sentiment']

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

acc_per_fold,precision_per_fold,recall_per_fold,f1_per_fold=crossval(x,y,'rf',vect,'weighted')
accuracy_crossval(acc_per_fold,f1_per_fold,precision_per_fold,recall_per_fold,'Random Forest Model')
# Out:
# ----------------------------------------
# Score per fold -  Random Forest Model
# ----------------------------------------
# > Fold 1
# Accuracy:  0.8115120787354608
# Precision:  0.820468881783149
# Recall:  0.8115120787354608
# F1:  0.7903295317128342
# ----------------------------------------
# > Fold 2
# Accuracy:  0.8303012227855652
# Precision:  0.8270449954756783
# Recall:  0.8303012227855652
# F1:  0.8226592506964072
# ----------------------------------------
# > Fold 3
# Accuracy:  0.7413484486873508
# Precision:  0.8038623927495289
# Recall:  0.7413484486873508
# F1:  0.7390468557964186
# ----------------------------------------
# Average scores for all folds:
# > Accuracy: 0.7943872500694589 (+- 0.038280489569944356)
# > Precision: 0.8171254233361188
# > Recall: 0.7943872500694589
# > F1: 0.7840118794018868

# %%
#df=df.reset_index()
x=df['cleanAnswer']
y=df['sentiment']

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

acc_per_fold,precision_per_fold,recall_per_fold,f1_per_fold=crossval(x,y,'svm',vect,'weighted')
accuracy_crossval(acc_per_fold,f1_per_fold,precision_per_fold,recall_per_fold,'SVM Model')
# Out:
# ----------------------------------------
# Score per fold -  SVM Model
# ----------------------------------------
# > Fold 1
# Accuracy:  0.7214434834476589
# Precision:  0.793829915370603
# Recall:  0.7214434834476589
# F1:  0.6549071414549124
# ----------------------------------------
# > Fold 2
# Accuracy:  0.8031613480465255
# Precision:  0.8195680816343387
# Recall:  0.8031613480465255
# F1:  0.8037225095966167
# ----------------------------------------
# > Fold 3
# Accuracy:  0.6056085918854416
# Precision:  0.7950259062248464
# Recall:  0.6056085918854416
# F1:  0.600378954993643
# ----------------------------------------
# Average scores for all folds:
# > Accuracy: 0.710071141126542 (+- 0.08105048013064314)
# > Precision: 0.8028079677432626
# > Recall: 0.710071141126542
# > F1: 0.6863362020150574

# %%
#df=df.reset_index()
x=df['cleanAnswer']
y=df['sentiment']

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

acc_per_fold,precision_per_fold,recall_per_fold,f1_per_fold=crossval(x,y,'nb',vect,'weighted')
accuracy_crossval(acc_per_fold,f1_per_fold,precision_per_fold,recall_per_fold,'Naive Bayes Model')
# Out:
# ----------------------------------------
# Score per fold -  Naive Bayes Model
# ----------------------------------------
# > Fold 1
# Accuracy:  0.779600357888458
# Precision:  0.7825955591256684
# Recall:  0.779600357888458
# F1:  0.7555358777093831
# ----------------------------------------
# > Fold 2
# Accuracy:  0.7980912615568148
# Precision:  0.7898039311577767
# Recall:  0.7980912615568148
# F1:  0.7824933553489286
# ----------------------------------------
# > Fold 3
# Accuracy:  0.7929594272076372
# Precision:  0.7819676760187013
# Recall:  0.7929594272076372
# F1:  0.7850862182387632
# ----------------------------------------
# Average scores for all folds:
# > Accuracy: 0.79021701555097 (+- 0.007793971853900084)
# > Precision: 0.7847890554340488
# > Recall: 0.79021701555097
# > F1: 0.7743718170990249

# %%
from sklearn.ensemble import GradientBoostingClassifier

#df=df.reset_index()
x=df['cleanAnswer']
y=df['sentiment']

vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}')
vect.fit(x)

acc_per_fold,precision_per_fold,recall_per_fold,f1_per_fold=crossval(x,y,'xgb',vect,'weighted')
accuracy_crossval(acc_per_fold,f1_per_fold,precision_per_fold,recall_per_fold,'Gradient Bossting Model')
