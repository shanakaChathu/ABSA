# %%
#Notes 

#https://medium.com/@saugata.paul1010/a-detailed-case-study-on-multi-label-classification-with-machine-learning-algorithms-and-72031742c9aa
#algorithm adaptation methods,
#https://www.causeweb.org/usproc/sites/default/files/usclap/2019-1/Comparison%20of%20Four%20Multi-Label%20Classification%20Methods.pdf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install scikit-multilearn
# Out:
# ...
#      |████████████████████████████████| 92kB 5.6MB/s
# ...

# %%
import pandas as pd 
import numpy as np 
from nltk.tokenize import word_tokenize
import re
from nltk.corpus import wordnet
import pandas as pd 
import numpy as np 
from nltk.tokenize import word_tokenize
import re
from sklearn.base import BaseEstimator, TransformerMixin
from nltk.corpus import wordnet
import pandas as pd 
import numpy as np 
import string
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('treebank')
from nltk.tag import UnigramTagger
from nltk.corpus import treebank
import pandas as pd 
import numpy as np 
import string
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec
#import fasttext
import gensim
from gensim.test.utils import datapath
from gensim.models import KeyedVectors
import seaborn as sns 
import re  # For preprocessing
from time import time  # To time our operations
from collections import defaultdict  # For word frequency
import spacy  # For preprocessing
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt 
from xlwt import Workbook 
import wordcloud
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.naive_bayes import MultinomialNB
#from xgboost import XGBClassifier
#import xgboost
import scipy.sparse


import time
import warnings

import nltk
nltk.download('stopwords')

#settings
start_time=time.time()
color = sns.color_palette()
sns.set_style("dark")
eng_stopwords = set(stopwords.words("english"))
warnings.filterwarnings("ignore")

from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 

from sklearn.model_selection import cross_validate
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import os
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import decomposition, ensemble
from scipy import interp
from itertools import cycle
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import nltk
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import warnings
import multiprocessing
from gensim.models import Word2Vec
#from gensim.models import FastText
from sklearn.metrics import roc_auc_score
from numpy import asarray
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import ClassifierChain

from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from nltk.tokenize import word_tokenize
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.preprocessing.text import Tokenizer
from numpy import array
from numpy import asarray
from numpy import zeros

from keras.models import Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation
from keras.layers import BatchNormalization
from keras.models import model_from_json
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.layers import BatchNormalization
from keras import backend as K
from sklearn.metrics import recall_score
from keras.models import load_model
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
import matplotlib.pyplot as pyplot

from keras.models import Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation
from keras.layers import BatchNormalization
from keras.models import model_from_json
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.layers import BatchNormalization
from keras import backend as K
from sklearn.metrics import recall_score
from keras.models import load_model
import tensorflow as tf 
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
mainloc='/content/drive/My Drive/Research/ABSA_Final/'
mainloc
# Out:
# '/content/drive/My Drive/Research/ABSA_Final/'

# %%
df=pd.read_csv(mainloc+"df_train.csv")
df=df[~df['cleanAnswer'].isna()]
print("Size of training dataset: ",df.shape)


df_we=pd.read_csv(mainloc+"Data/data_clean_full_corpus.csv")
df_we=df_we[~df_we['cleanAnswer'].isna()]
print("Size of word embedding dataset: ",df_we.shape)

df.head(2)

# %%
#Functions 

def splitdata(df,feat,categories,splitratio,valflag):
    x =df[feat]
    y =df[categories]
    x_train_main, x_test, y_train_main, y_test = train_test_split(x, y, test_size=splitratio, random_state=100)
    x_train, x_val, y_train, y_val = train_test_split(x_train_main, y_train_main, test_size=splitratio, random_state=100)
    
    if(valflag):
        return x, y, x_train,x_val,x_test,y_train,y_val, y_test
    else:
        return x, y, x_train_main,x_test,y_train_main, y_test

    
def accuracymeasures(y_test,predictions,prediction_prob):
    
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    f1score = f1_score(y_test, predictions)
    #auc= roc_auc_score(label_binarize(y_test, classes=[0,1]), prediction_prob)
    
    #target_names = [0,1]
    print("Classification report")
    print("---------------------","\n")
    print(classification_report(y_test, predictions),"\n")
    print("Confusion Matrix")
    print("---------------------","\n")
    print(confusion_matrix(y_test, predictions),"\n")

    print("Accuracy Measures")
    print("---------------------","\n")
    #print("AUC: ",auc)
    print("Accuracy: ", accuracy)
    print("Precision: ", precision)
    print("Recall: ", recall)
    print("F1 Score: ", f1score)
    
    
def train_model(classifier, feature_vector_train, label):
    classifier.fit(feature_vector_train, label)
    return classifier
        
def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    predictions_prob = clf.predict_proba(feature_vector_valid)
    return predictions, predictions_prob

def multiclassroc(y_test,prediction_prob):
    fpr = {}
    tpr = {}
    thresh ={}
    
    n_class = 3
    for i in range(n_class):    
        fpr[i], tpr[i], thresh[i] = roc_curve(y_test, prediction_prob[:,i], pos_label=i)
        
    plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Passive vs Rest')
    plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Neutral vs Rest')
    plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Positive vs Rest')
    plt.title('Multiclass ROC curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive rate')
    plt.legend(loc='best')
    #plt.savefig('Multiclass ROC',dpi=300)
    
def precrecallcurve(y_test_c, prediction_prob):
    precision = dict()
    recall = dict()
    for i in range(3):
        precision[i], recall[i], _ = precision_recall_curve(y_test_c[:, i],prediction_prob[:, i])
        plt.plot(recall[i], precision[i], lw=2, label='class {}'.format(i))
    
    plt.xlabel("recall")
    plt.ylabel("precision")
    plt.legend(loc="best")
    plt.title("precision vs. recall curve")
    plt.show()

# %% [markdown]
# # OnevsRest Method

# %%
#With lightgbm 
categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(df,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

#validation
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

#Testing 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

xtrain_vect=xtrain_vect_count.astype('float32')
xval_vect=xval_vect_count.astype('float32')
xtest_vect=xtest_vect_count.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

for category in categories:
    encoder = preprocessing.LabelEncoder()
    y_train_cat= encoder.fit_transform(y_train[category])
    y_val_cat= encoder.fit_transform(y_val[category])
    y_test_cat= encoder.fit_transform(y_test[category])
    
    print('\n**Processing {} comments...**'.format(category))
    fit_params = {'early_stopping_rounds': 10, 
              'eval_metric' : 'auc', 
              'eval_set' : [(xtrain_vect, y_train_cat),(xval_vect, y_val_cat)],
              'eval_names': ['train','valid'],
              'verbose': 10,
              'feature_name': 'auto', 
             }
    
    model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', max_depth=3,
                              objective='binary', random_state=1,reg_alpha=0.3,reg_lambda=0.3,n_estimators=100)
    model.fit(xtrain_vect, y_train_cat, **fit_params)
    
    print("\n","*******Training accuracy scores*******")
    print("--------------------------------------------","\n")
    predictions,prediction_prob=pred(model,xtrain_vect)
    accuracymeasures(y_train_cat, predictions,prediction_prob)

    print("\n","*******Validation accuracy scores*******")
    print("----------------------------------------------","\n")
    predictions,prediction_prob=pred(model,xval_vect)
    accuracymeasures(y_val_cat, predictions,prediction_prob)
    
    print("\n","*******Testing accuracy scores*******")
    print("--------------------------------------------","\n")
    predictions,prediction_prob=pred(model,xtest_vect)
    accuracymeasures(y_test_cat, predictions,prediction_prob)
# Out:
# **Processing network comments...**
# Training until validation scores don't improve for 10 rounds.
# [10]	train's auc: 0.853984	train's binary_logloss: 0.488367	valid's auc: 0.855737	valid's binary_logloss: 0.483696
# [20]	train's auc: 0.892268	train's binary_logloss: 0.423767	valid's auc: 0.899454	valid's binary_logloss: 0.414491
# [30]	train's auc: 0.901547	train's binary_logloss: 0.388745	valid's auc: 0.904997	valid's binary_logloss: 0.378176
# [40]	train's auc: 0.923394	train's binary_logloss: 0.364513	valid's auc: 0.931717	valid's binary_logloss: 0.353237
# [50]	train's auc: 0.93942	train's binary_logloss: 0.346664	valid's auc: 0.945623	valid's binary_logloss: 0.335256
# [60]	train's auc: 0.948036	train's binary_logloss: 0.332213	valid's auc: 0.946427	valid's binary_logloss: 0.321611
# [70]	train's auc: 0.952464	train's binary_logloss: 0.320947	valid's auc: 0.948387	valid's binary_logloss: 0.312818
# ...

# %%
def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='weighted'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='weighted'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='weighted'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    #predictions_prob = clf.predict_proba(feature_vector_valid)
    #return predictions, predictions_prob    
    return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

#validation
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

#Testing 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

xtrain_vect=xtrain_vect_count.astype('float32')
xval_vect=xval_vect_count.astype('float32')
xtest_vect=xtest_vect_count.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')


#Create various models. These are multi-label models.
nb_classif = OneVsRestClassifier(MultinomialNB()).fit(xtrain_vect, y_train)
C = 1.0 #SVregularization parameter
svc_linear = OneVsRestClassifier(svm.SVC(kernel='linear', C=C,probability=True)).fit(xtrain_vect, y_train)
svc_rbf = OneVsRestClassifier(svm.SVC(kernel='rbf',probability=True)).fit(xtrain_vect, y_train)
sgd = OneVsRestClassifier(SGDClassifier()).fit(xtrain_vect, y_train)
lr=OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=-1).fit(xtrain_vect, y_train)
lgb_model=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced')).fit(xtrain_vect, y_train)

print("Accuracy of Logistic Regression Model")
print("--------------------------------------------")
predictions = pred(lr,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of Light gbm Model")
print("--------------------------------------------")
predictions = pred(lgb_model,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of Multinomial Naive Bayes Model")
print("--------------------------------------------")
predictions = pred(nb_classif,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of SVC with Linear kernal Model")
print("--------------------------------------------")
predictions = pred(svc_linear,xval_vect,True)
accuracy(y_val,predictions)

print("Accuracy of SGD Model")
print("--------------------------------------------")
predictions = pred(sgd,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of SVC with RBF kernal Model")
print("--------------------------------------------")
predictions = pred(svc_rbf,xval_vect,True)
accuracy(y_val,predictions)

# %%
def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='weighted'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='weighted'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='weighted'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    #predictions_prob = clf.predict_proba(feature_vector_valid)
    #return predictions, predictions_prob    
    return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(df,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtrain_vect_count12= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtrain_vect_count13= count_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf= tfidf_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf12= tfidf_vect.transform(x_train).astype('float32')

#Testing 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtest_vect_count12= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtest_vect_count13= count_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf= tfidf_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf12= tfidf_vect.transform(x_test).astype('float32')


#validation

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xval_vect_count12= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xval_vect_count13= count_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf= tfidf_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf12= tfidf_vect.transform(x_val).astype('float32')

xtrain_vect=scipy.sparse.hstack([xtrain_vect_count, xtrain_vect_tfidf,xtrain_vect_tfidf12,xtrain_vect_count12,xtrain_vect_count13])
xval_vect=scipy.sparse.hstack([xval_vect_count, xval_vect_tfidf,xval_vect_tfidf12,xval_vect_count12,xval_vect_count13])
xtest_vect=scipy.sparse.hstack([xtest_vect_count, xtest_vect_tfidf,xtest_vect_tfidf12,xtest_vect_count12,xtest_vect_count13])
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

print(1)

#Create various models. These are multi-label models.
#nb_classif = OneVsRestClassifier(MultinomialNB()).fit(xtrain_vect, y_train)
#C = 1.0 #SVregularization parameter
svc_linear = OneVsRestClassifier(svm.SVC(kernel='linear', C=C,probability=True)).fit(xtrain_vect, y_train)
#svc_rbf = OneVsRestClassifier(svm.SVC(kernel='rbf',probability=True)).fit(xtrain_vect, y_train)
#sgd = OneVsRestClassifier(SGDClassifier()).fit(xtrain_vect, y_train)
#lr=OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=-1).fit(xtrain_vect, y_train)
#lgb_model=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced')).fit(xtrain_vect, y_train)

print("Accuracy of Logistic Regression Model")
print("--------------------------------------------")
predictions = pred(lr,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of Light gbm Model")
print("--------------------------------------------")
predictions = pred(lgb_model,xval_vect,False)
accuracy(y_val,predictions)

nb_classif = OneVsRestClassifier(MultinomialNB()).fit(xtrain_vect, y_train)
print("Accuracy of Multinomial Naive Bayes Model")
print("--------------------------------------------")
predictions = pred(nb_classif,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of SVC with Linear kernal Model")
print("--------------------------------------------")
predictions = pred(svc_linear,xval_vect,True)
accuracy(y_val,predictions)

print("Accuracy of SGD Model")
print("--------------------------------------------")
predictions = pred(sgd,xval_vect,False)
accuracy(y_val,predictions)

print("Accuracy of SVC with RBF kernal Model")
print("--------------------------------------------")
predictions = pred(svc_rbf,xval_vect,True)
accuracy(y_val,predictions)

# %%
def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='weighted'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='weighted'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='weighted'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    #predictions_prob = clf.predict_proba(feature_vector_valid)
    #return predictions, predictions_prob    
    return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(df,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtrain_vect_count12= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtrain_vect_count13= count_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf= tfidf_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf12= tfidf_vect.transform(x_train).astype('float32')

#Testing 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtest_vect_count12= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtest_vect_count13= count_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf= tfidf_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf12= tfidf_vect.transform(x_test).astype('float32')


#validation

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xval_vect_count12= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xval_vect_count13= count_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf= tfidf_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf12= tfidf_vect.transform(x_val).astype('float32')

xtrain_vect=scipy.sparse.hstack([xtrain_vect_count, xtrain_vect_tfidf,xtrain_vect_tfidf12,xtrain_vect_count12,xtrain_vect_count13])
xval_vect=scipy.sparse.hstack([xval_vect_count, xval_vect_tfidf,xval_vect_tfidf12,xval_vect_count12,xval_vect_count13])
xtest_vect=scipy.sparse.hstack([xtest_vect_count, xtest_vect_tfidf,xtest_vect_tfidf12,xtest_vect_count12,xtest_vect_count13])
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

C = 1.0
svc_linear = OneVsRestClassifier(svm.SVC(kernel='linear', C=C,probability=True)).fit(xtrain_vect, y_train)

# %%
print("Accuracy of SVC with Linear kernal Model")
print("--------------------------------------------")
predictions = pred(svc_linear,xval_vect)
accuracy(y_val,predictions)
# Out:
# Accuracy of SVC with Linear kernal Model
# --------------------------------------------
# Accuracy Score:  0.5267080745341615
# Precision:  0.8515718205860346
# Recall:  0.7399926551597503
# F1 score:  0.7864709684939813
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.91      0.80      0.85       440
#    billing_price       0.83      0.60      0.70       443
#          package       0.93      0.72      0.81       288
# customer_service       0.88      0.53      0.66       224
#             data       0.84      0.74      0.79       452
#  service_product       0.80      0.84      0.82       876
#
#        micro avg       0.85      0.74      0.79      2723
#        macro avg       0.87      0.71      0.77      2723
#     weighted avg       0.85      0.74      0.79      2723
#      samples avg       0.84      0.78      0.78      2723

# %%
#lr=OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=-1).fit(xtrain_vect, y_train)
print("Accuracy of Logistic regression Model")
print("--------------------------------------------")
predictions = pred(lr,xval_vect)
accuracy(y_val,predictions)
# Out:
# Accuracy of Logistic regression Model
# --------------------------------------------
# Accuracy Score:  0.49130434782608695
# Precision:  0.8357754921041619
# Recall:  0.7084098420859346
# F1 score:  0.761722640006602
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.90      0.77      0.83       440
#    billing_price       0.81      0.58      0.68       443
#          package       0.88      0.65      0.75       288
# customer_service       0.83      0.46      0.59       224
#             data       0.81      0.71      0.76       452
#  service_product       0.82      0.82      0.82       876
#
#        micro avg       0.84      0.71      0.77      2723
#        macro avg       0.84      0.67      0.74      2723
#     weighted avg       0.84      0.71      0.76      2723
#      samples avg       0.83      0.75      0.76      2723

# %%
lgb_model=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced')).fit(xtrain_vect, y_train)

print("Accuracy of Light gbm Model")
print("--------------------------------------------")
predictions = pred(lgb_model,xval_vect)
accuracy(y_val,predictions)
# Out:
# Accuracy of Light gbm Model
# --------------------------------------------
# Accuracy Score:  0.5080745341614907
# Precision:  0.791376765157485
# Recall:  0.8049944913698127
# F1 score:  0.7979793099243567
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.85      0.85      0.85       440
#    billing_price       0.73      0.75      0.74       443
#          package       0.80      0.82      0.81       288
# customer_service       0.68      0.69      0.69       224
#             data       0.80      0.86      0.83       452
#  service_product       0.81      0.81      0.81       876
#
#        micro avg       0.79      0.80      0.80      2723
#        macro avg       0.78      0.80      0.79      2723
#     weighted avg       0.79      0.80      0.80      2723
#      samples avg       0.81      0.83      0.79      2723

# %%
sgd = OneVsRestClassifier(SGDClassifier()).fit(xtrain_vect, y_train)


print("Accuracy of SGD Model")
print("--------------------------------------------")
predictions = pred(sgd,xval_vect)
accuracy(y_val,predictions)
# Out:
# Accuracy of SGD Model
# --------------------------------------------
# Accuracy Score:  0.5012422360248447
# Precision:  0.8236517491371489
# Recall:  0.7179581344105765
# F1 score:  0.7626327418234502
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.89      0.73      0.81       440
#    billing_price       0.80      0.57      0.66       443
#          package       0.89      0.71      0.79       288
# customer_service       0.80      0.56      0.66       224
#             data       0.82      0.71      0.76       452
#  service_product       0.79      0.83      0.81       876
#
#        micro avg       0.82      0.72      0.77      2723
#        macro avg       0.83      0.69      0.75      2723
#     weighted avg       0.82      0.72      0.76      2723
#      samples avg       0.81      0.75      0.75      2723

# %%
nb_classif = OneVsRestClassifier(MultinomialNB()).fit(xtrain_vect, y_train)
print("Accuracy of Multinomial Naive Bayes Model")
print("--------------------------------------------")
predictions = pred(nb_classif,xval_vect)
accuracy(y_val,predictions)
# Out:
# Accuracy of Multinomial Naive Bayes Model
# --------------------------------------------
# Accuracy Score:  0.40869565217391307
# Precision:  0.7160260700362421
# Recall:  0.7036356959236136
# F1 score:  0.7087966891966722
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.74      0.78      0.76       440
#    billing_price       0.69      0.70      0.69       443
#          package       0.61      0.66      0.63       288
# customer_service       0.54      0.55      0.55       224
#             data       0.62      0.64      0.63       452
#  service_product       0.85      0.76      0.80       876
#
#        micro avg       0.71      0.70      0.71      2723
#        macro avg       0.67      0.68      0.68      2723
#     weighted avg       0.72      0.70      0.71      2723
#      samples avg       0.76      0.76      0.72      2723

# %%
#Experiments with lightgbm model 

def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    predictions_prob = clf.predict_proba(feature_vector_valid)
    return predictions, predictions_prob    
    #return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtrain_vect_count12= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtrain_vect_count13= count_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf= tfidf_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf12= tfidf_vect.transform(x_train).astype('float32')

#Testing 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtest_vect_count12= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtest_vect_count13= count_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf= tfidf_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf12= tfidf_vect.transform(x_test).astype('float32')


#validation

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xval_vect_count12= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xval_vect_count13= count_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf= tfidf_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf12= tfidf_vect.transform(x_val).astype('float32')

xtrain_vect=scipy.sparse.hstack([xtrain_vect_count, xtrain_vect_tfidf,xtrain_vect_tfidf12,xtrain_vect_count12,xtrain_vect_count13])
xval_vect=scipy.sparse.hstack([xval_vect_count, xval_vect_tfidf,xval_vect_tfidf12,xval_vect_count12,xval_vect_count13])
xtest_vect=scipy.sparse.hstack([xtest_vect_count, xtest_vect_tfidf,xtest_vect_tfidf12,xtest_vect_count12,xtest_vect_count13])
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

fit_params = {#'early_stopping_rounds': 10, 
              'eval_metric' : 'auc', 
              'eval_set' : [(xtrain_vect,y_train),(xval_vect,y_val)],
              'eval_names': ['train','valid'],
              'verbose': 10,
              'feature_name': 'auto', 
             }

lgb_model = lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced', objective='binary', random_state=1,
                          reg_alpha=0.3,reg_lambda=0.3,n_estimators=10,)

lgb_model=OneVsRestClassifier(lgb_model).fit(xtrain_vect, y_train)

print("Accuracy of Light gbm Model")
print("--------------------------------------------")
predictions,predictions_prob = pred(lgb_model,xtest_vect)
accuracy(y_test,predictions)
# Out:
# Accuracy of Light gbm Model
# --------------------------------------------
# Accuracy Score:  0.30241187384044527
# Precision:  0.620754716981132
# Recall:  0.7633410672853829
# F1 score:  0.6847034339229968
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.66      0.82      0.73       130
#    billing_price       0.45      0.76      0.57       127
#          package       0.61      0.66      0.64       116
# customer_service       0.38      0.49      0.43        51
#             data       0.70      0.87      0.77       171
#  service_product       0.72      0.77      0.75       267
#
#        micro avg       0.62      0.76      0.68       862
#        macro avg       0.59      0.73      0.65       862
#     weighted avg       0.63      0.76      0.69       862
#      samples avg       0.65      0.78      0.68       862

# %%
lgb_model = lgb.LGBMClassifier(boosting_type='gbdt',
                               #class_weight='balanced',
                               objective='binary',
                               random_state=1,
                               max_depth =3,
                               reg_alpha=0.7,
                               reg_lambda=0.7,
                               n_estimators=1000)

lgb_model=OneVsRestClassifier(lgb_model).fit(xtrain_vect, y_train)
print("Accuracy of Light gbm Model")
print("--------------------------------------------")

print("\nTraiing accuracy")
print("--------------------------------------------")
predictions = pred(lgb_model,xtrain_vect)
accuracy(y_train,predictions)

print("\nValidation accuracy")
print("--------------------------------------------")
predictions = pred(lgb_model,xval_vect)
accuracy(y_val,predictions)

print("\n Testing accuracy")
print("--------------------------------------------")
predictions = pred(lgb_model,xtest_vect)
accuracy(y_test,predictions)
# Out:
# Accuracy of Light gbm Model
# --------------------------------------------
#
# Traiing accuracy
# --------------------------------------------
# Accuracy Score:  0.8013937282229965
# Precision:  0.9496657491152183
# Recall:  0.8810653046333455
# F1 score:  0.9140802422407267
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.99      0.89      0.94       459
#    billing_price       0.98      0.75      0.85       349
#          package       0.98      0.86      0.91       357
# customer_service       1.00      0.79      0.88       192
#             data       0.96      0.90      0.93       548
#  service_product       0.89      0.94      0.92       836
#
#        micro avg       0.95      0.88      0.91      2741
#        macro avg       0.97      0.86      0.91      2741
#     weighted avg       0.95      0.88      0.91      2741
#      samples avg       0.92      0.89      0.90      2741
#
#
# ...

# %%
#Binary relevence classifier 


def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    #predictions_prob = clf.predict_proba(feature_vector_valid)
    #return predictions, predictions_prob    
    return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

#validation
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

#Testing 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

xtrain_vect=xtrain_vect_count.astype('float32')
xval_vect=xval_vect_count.astype('float32')
xtest_vect=xtest_vect_count.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

#Create various models. These are multi-label models.
#nb_classif = BinaryRelevance(MultinomialNB()).fit(xtrain_vect, y_train)
#C = 1.0 #SVregularization parameter
#svc_linear = BinaryRelevance(svm.SVC(kernel='linear', C=C,probability=True)).fit(xtrain_vect, y_train)
#svc_rbf = OneVsRestClassifier(svm.SVC(kernel='rbf',probability=True)).fit(xtrain_vect, y_train)
#sgd = BinaryRelevance(SGDClassifier()).fit(xtrain_vect, y_train)
lr=BinaryRelevance(LogisticRegression(solver='sag',class_weight='balanced')).fit(xtrain_vect, y_train)
##lgb_model=BinaryRelevance(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced')).fit(xtrain_vect, y_train)


print("\nTraiing accuracy")
print("--------------------------------------------")
predictions = pred(lr,xtrain_vect)
accuracy(y_train,predictions)

print("Accuracy of Logistic Regression Model")
print("--------------------------------------------")
predictions = pred(lr,xval_vect)
accuracy(y_val,predictions)
# Out:
# Traiing accuracy
# --------------------------------------------
# Accuracy Score:  0.9326364692218351
# Precision:  0.9615384615384616
# Recall:  0.9941627143378329
# F1 score:  0.9775784753363229
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.97      1.00      0.99       459
#    billing_price       0.93      1.00      0.96       349
#          package       0.95      1.00      0.97       357
# customer_service       0.96      1.00      0.98       192
#             data       0.95      1.00      0.98       548
#  service_product       0.98      0.98      0.98       836
#
#        micro avg       0.96      0.99      0.98      2741
#        macro avg       0.96      1.00      0.98      2741
#     weighted avg       0.96      0.99      0.98      2741
#      samples avg       0.97      0.99      0.98      2741
#
# Accuracy of Logistic Regression Model
# ...

# %%
def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    #predictions_prob = clf.predict_proba(feature_vector_valid)
    #return predictions, predictions_prob    
    return predictions

#categories=['network','billing_price','package','customer_service','data','service_product']   
#x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(df,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

#validation
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

#Testing 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

xtrain_vect=xtrain_vect_count.astype('float32')
xval_vect=xval_vect_count.astype('float32')
xtest_vect=xtest_vect_count.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

#Create various models. These are multi-label models.
nb_classif = ClassifierChain(MultinomialNB()).fit(xtrain_vect, y_train)
C = 1.0 #SVregularization parameter
svc_linear = ClassifierChain(svm.SVC(kernel='linear', C=C,probability=True)).fit(xtrain_vect, y_train)
svc_rbf = ClassifierChain(svm.SVC(kernel='rbf',probability=True)).fit(xtrain_vect, y_train)
sgd = ClassifierChain(SGDClassifier()).fit(xtrain_vect, y_train)
lr=ClassifierChain(LogisticRegression(solver='sag',class_weight='balanced')).fit(xtrain_vect, y_train)
lgb_model=ClassifierChain(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced')).fit(xtrain_vect, y_train)

print("Accuracy of Logistic Regression Model")
print("--------------------------------------------")
predictions = pred(lr,xval_vect)
accuracy(y_val,predictions)

print("Accuracy of Light gbm Model")
print("--------------------------------------------")
predictions = pred(lgb_model,xval_vect)
accuracy(y_val,predictions)

print("Accuracy of Multinomial Naive Bayes Model")
print("--------------------------------------------")
predictions = pred(nb_classif,xval_vect)
accuracy(y_val,predictions)

print("Accuracy of SVC with Linear kernal Model")
print("--------------------------------------------")
predictions = pred(svc_linear,xval_vect)
accuracy(y_val,predictions)

print("Accuracy of SGD Model")
print("--------------------------------------------")
predictions = pred(sgd,xval_vect)
accuracy(y_val,predictions)

print("Accuracy of SVC with RBF kernal Model")
print("--------------------------------------------")
predictions = pred(svc_rbf,xval_vect)
accuracy(y_val,predictions)

# %%
def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))


def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    #predictions_prob = clf.predict_proba(feature_vector_valid)
    #return predictions, predictions_prob    
    return predictions

#categories=['network','billing_price','package','customer_service','data','service_product']   
#x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(df,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

#validation
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

#Testing 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

xtrain_vect=xtrain_vect_count.astype('float32')
xval_vect=xval_vect_count.astype('float32')
xtest_vect=xtest_vect_count.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

#Create various models. These are multi-label models.
lr=ClassifierChain(LogisticRegression(solver='sag',class_weight='balanced')).fit(xtrain_vect, y_train)

print("Accuracy of Logistic Regression Model")
print("--------------------------------------------")
predictions = pred(lr,xval_vect)
accuracy(y_val,predictions)
# Out:
# Accuracy of Logistic Regression Model
# --------------------------------------------
# Accuracy Score:  0.5260869565217391
# Precision:  0.8024737631184408
# Recall:  0.786265148733015
# F1 score:  0.7942867742533851
#
# Classification report
# ---------------------
#                   precision    recall  f1-score   support
#
#          network       0.86      0.85      0.86       440
#    billing_price       0.74      0.71      0.72       443
#          package       0.84      0.80      0.82       288
# customer_service       0.69      0.67      0.68       224
#             data       0.81      0.79      0.80       452
#  service_product       0.81      0.81      0.81       876
#
#        micro avg       0.80      0.79      0.79      2723
#        macro avg       0.79      0.77      0.78      2723
#     weighted avg       0.80      0.79      0.79      2723
#      samples avg       0.83      0.82      0.80      2723

# %%
#Parameter tunning with OVR method 

def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))

def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    predictions_prob = clf.predict_proba(feature_vector_valid)
    return predictions, predictions_prob    
    #return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_test,y_train,y_test=splitdata(aspect,'cleanAnswer',categories,0.2,False)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

#validation
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

#Testing 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

xtrain_vect=xtrain_vect_count.astype('float32')
xval_vect=xval_vect_count.astype('float32')
xtest_vect=xtest_vect_count.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')

grid_values = {'estimator__max_depth': [1,2,3,4,5],
               'estimator__num_leaves': [5,10,15,20,25],             
               'estimator__subsample' : [0.1,0.2],
               'estimator__colsample_bytree' : [0.1,0.2,0.3],               
               'estimator__max_bin': [5,10,15,20],
               'estimator__min_data_in_leaf': [1,3,4],
               'estimator__reg_lambda': [ 0.01],
              } 


grid_values = {'estimator__max_depth': [5,6,7,8],
               'estimator__num_leaves': [5,6,7],
               'estimator__max_bin': [5,6,7,8],
               'estimator__min_data_in_leaf': [4,5,6,7,9,10],
               'estimator__colsample_bytree' : [0.1,0.2,0.3,0.5,0.7],
                'estimator__subsample' : [0.1,0.2,0.4,0.6],
               
              }

#clf.get_params().keys()
clf=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced'))

grid_clf = GridSearchCV(clf,param_grid = grid_values, scoring = 'f1_macro', n_jobs=-1, verbose=10, cv=3)
grid_clf.fit(xtrain_vect, y_train)

print("Best estimator: ",grid_clf.best_estimator_)
print("Best Cross Validation Score: ",grid_clf.best_score_)

model = grid_clf.best_estimator_
print("Accuracy of Lightgbm  Model(Train)")
print("--------------------------------------------")
predictions,predictions_prob = pred(model,xtrain_vect)
accuracy(y_train,predictions)

model = grid_clf.best_estimator_
print("Accuracy of Lightgbm Model(Test)")
print("--------------------------------------------")
predictions,predictions_prob = pred(model,xtest_vect)
accuracy(y_test,predictions)
# Out:
# Fitting 3 folds for each of 5760 candidates, totalling 17280 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:   26.0s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   28.5s
# ...

# %%
#Parameter tunning with OVR method
#countvect and tfidf both 

def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))

def pred(clf, feature_vector_valid):
    predictions = clf.predict(feature_vector_valid)
    predictions_prob = clf.predict_proba(feature_vector_valid)
    return predictions, predictions_prob    
    #return predictions

categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_test,y_train,y_test=splitdata(aspect,'cleanAnswer',categories,0.2,False)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtrain_vect_count12= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtrain_vect_count13= count_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf= tfidf_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf12= tfidf_vect.transform(x_train).astype('float32')

#Testing 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtest_vect_count12= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtest_vect_count13= count_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf= tfidf_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf12= tfidf_vect.transform(x_test).astype('float32')

xtrain_vect=scipy.sparse.hstack([xtrain_vect_count, xtrain_vect_tfidf,xtrain_vect_tfidf12,xtrain_vect_count12,xtrain_vect_count13])
xtest_vect=scipy.sparse.hstack([xtest_vect_count, xtest_vect_tfidf,xtest_vect_tfidf12,xtest_vect_count12,xtest_vect_count13])
y_train=y_train.astype('float32')
y_test=y_test.astype('float32')

grid_values = {'estimator__max_depth': [1,2,3,4,5],
               'estimator__num_leaves': [5,10,15,20,25],             
               'estimator__subsample' : [0.1,0.2],
               'estimator__colsample_bytree' : [0.1,0.2,0.3],               
               'estimator__max_bin': [5,10,15,20],
               'estimator__min_data_in_leaf': [1,3,4],
               'estimator__reg_lambda': [ 0.01],
              } 


grid_values = {'estimator__max_depth': [1,2,3,4,5,6],
               'estimator__num_leaves': [4,5,6,7],
               'estimator__max_bin': [5,10,15,20],
               'estimator__min_data_in_leaf': [1,3,4],
               'estimator__colsample_bytree' : [0.1,0.2,0.3],     
              'estimator__subsample' : [0.1,0.2,0.6,0.4],
              }



grid_values = {'estimator__max_depth': [5,6,7,8],
               'estimator__num_leaves': [5,6,7],
               'estimator__max_bin': [5,6,7,8],
               'estimator__min_data_in_leaf': [4,5,6,7],
               'estimator__colsample_bytree' : [0.1,0.2,0.3,0.5],
                'estimator__subsample' : [0.1,0.2],
               
              }

#clf.get_params().keys()
clf=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced'))

grid_clf = GridSearchCV(clf,param_grid = grid_values, scoring = 'f1_macro', n_jobs=-1, verbose=10, cv=3)
grid_clf.fit(xtrain_vect, y_train)

print("Best estimator: ",grid_clf.best_estimator_)
print("Best Cross Validation Score: ",grid_clf.best_score_)

model = grid_clf.best_estimator_
print("Accuracy of Lightgbm  Model")
print("--------------------------------------------")
predictions,predictions_prob = pred(model,xtrain_vect)
accuracy(y_train,predictions)

model = grid_clf.best_estimator_
print("Accuracy of Lightgbm Model")
print("--------------------------------------------")
predictions,predictions_prob = pred(model,xtest_vect)
accuracy(y_test,predictions)

# %% [markdown]
# # Models with word embeddings

# %%
#Word embedding with multiclass classifier 

#Word embeddings 

def create_txt(df,var):
    text=[]
    for i in df[var]:
        li = list(i.split())
        text.append(li)
    return text
        
def word2vec(text,min_count,size,workers,window,sg):
    model = Word2Vec(text,min_count=min_count,size=size,workers=workers,window=window,sg=sg)
    return model 

def make_feature_vec(words, model, num_features):
    """
    Average the word vectors for a set of words
    """
    feature_vec = np.zeros((num_features,),dtype="float32")  # pre-initialize (for speed)
    nwords = 0
    index2word_set = set(model.wv.index2word)  # words known to the model
   

    for word in words:
        if word in index2word_set: 
            nwords = nwords + 1
            feature_vec = np.add(feature_vec,model[word])
    
    feature_vec = np.divide(feature_vec, nwords)
    return feature_vec

def get_avg_feature_vecs(reviews, model, num_features):
    """
    Calculate average feature vectors for all reviews
    """
    counter = 0
    review_feature_vecs = np.zeros((len(reviews),num_features), dtype='float32')  # pre-initialize (for speed)
    
    for review in reviews:
        review_feature_vecs[counter] = make_feature_vec(review, model, num_features)
        counter = counter + 1
    return review_feature_vecs

def splitdata_we(x,y, feat,target,splitratio,valflag):
    x_train_main, x_test, y_train_main, y_test = train_test_split(x, y, test_size=splitratio, random_state=10, stratify=y)
    x_train, x_val, y_train, y_val = train_test_split(x_train_main, y_train_main, test_size=splitratio, random_state=10, 
                                                      stratify=y_train_main)
    encoder = preprocessing.LabelEncoder()
    y_train_main = encoder.fit_transform(y_train_main)
    y_train = encoder.fit_transform(y_train)
    y_val = encoder.fit_transform(y_val)
    y_test = encoder.fit_transform(y_test)
    
    y_train_main_c = label_binarize(y_train_main, classes=[0,1,2])
    y_train_c = label_binarize(y_train, classes=[0,1,2])
    y_val_c = label_binarize(y_val, classes=[0,1,2])
    y_test_c = label_binarize(y_test, classes=[0,1,2])
    
    if(valflag):
        return x, y, x_train,x_val,x_test,y_train,y_val, y_test,y_train_c,y_val_c,y_test_c 
    else:
        return x, y, x_train_main,x_test,y_train_main, y_test, y_train_main_c,y_test_c

    
def word_embed(df,num_features,wetype,window,sg):
    df_we=pd.read_csv("../Data/data_after_clean.csv")
    df_we=df_we[~(df_we['cleanAnswer'].isna())]
    text_we=create_txt(df_we,'cleanAnswer')
    text_model=create_txt(df,'cleanAnswer')
    
    if(wetype=='cbow'):
        model=word2vec(text_we,1,num_features,7,window,sg)
        
    if(wetype=='ft'):
        model = FastText(text_we,size=num_features,window=window,sg=sg,iter=100)

    x=get_avg_feature_vecs(text_model,model, num_features)
    return x 

def splitdata_we(x,y,splitratio,valflag):
    x_train_main, x_test, y_train_main, y_test = train_test_split(x, y, test_size=splitratio, random_state=10)
    x_train, x_val, y_train, y_val = train_test_split(x_train_main, y_train_main, test_size=splitratio, random_state=10)
    
    if(valflag):
        return x, y, x_train,x_val,x_test,y_train,y_val, y_test 
    else:
        return x, y, x_train_main,x_test,y_train_main, y_test

# %%
#Making word embeddings 
x_cbow=word_embed(aspect,300,'cbow',10,1)
# Out:
# INFO - 21:01:49: collecting all words and their counts
# INFO - 21:01:49: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 21:01:49: PROGRESS: at sentence #10000, processed 77259 words, keeping 12800 word types
# INFO - 21:01:49: PROGRESS: at sentence #20000, processed 138029 words, keeping 19574 word types
# INFO - 21:01:49: PROGRESS: at sentence #30000, processed 209058 words, keeping 25833 word types
# INFO - 21:01:49: PROGRESS: at sentence #40000, processed 258522 words, keeping 30869 word types
# INFO - 21:01:49: PROGRESS: at sentence #50000, processed 315591 words, keeping 38029 word types
# INFO - 21:01:49: PROGRESS: at sentence #60000, processed 386423 words, keeping 44811 word types
# INFO - 21:01:49: PROGRESS: at sentence #70000, processed 452209 words, keeping 51106 word types
# INFO - 21:01:49: PROGRESS: at sentence #80000, processed 506922 words, keeping 57472 word types
# ...

# %%
categories=['network','billing_price','package','customer_service','data','service_product']   
x=x_cbow
y = aspect[categories]
        
x, y, x_train,x_test,y_train,y_test=splitdata_we(x,y,0.2,False)

xtrain_vect=x_train.astype('float32')
xtest_vect=x_test.astype('float32')
y_train=y_train.astype('float32')
y_test=y_test.astype('float32')


#Create various models. These are multi-label models.
#nb_classif = OneVsRestClassifier(MultinomialNB()).fit(xtrain_vect, y_train)
C = 1.0 #SVregularization parameter
svc_linear = OneVsRestClassifier(svm.SVC(kernel='linear', C=C,probability=True)).fit(xtrain_vect, y_train)
#svc_rbf = OneVsRestClassifier(svm.SVC(kernel='rbf',probability=True)).fit(xtrain_vect, y_train)
sgd = OneVsRestClassifier(SGDClassifier()).fit(xtrain_vect, y_train)
lr=OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=-1).fit(xtrain_vect, y_train)
lgb_model=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced')).fit(xtrain_vect, y_train)

print("Accuracy of Logistic Regression Model")
print("--------------------------------------------")
predictions, predictions_prob   = pred(lr,xtest_vect)
accuracy(y_test,predictions)

print("Accuracy of Light gbm Model")
print("--------------------------------------------")
predictions, predictions_prob   = pred(lgb_model,xtest_vect)
accuracy(y_test,predictions)

print("Accuracy of Multinomial Naive Bayes Model")
print("--------------------------------------------")
predictions, predictions_prob   = pred(nb_classif,xtest_vect)
accuracy(y_test,predictions)

print("Accuracy of SVC with Linear kernal Model")
print("--------------------------------------------")
predictions, predictions_prob   = pred(svc_linear,xtest_vect)
accuracy(y_test,predictions)

print("Accuracy of SVC with RBF kernal Model")
print("--------------------------------------------")
predictions, predictions_prob   = pred(svc_rbf,xtest_vect)
accuracy(y_test,predictions)

# %%
categories=['network','billing_price','package','customer_service','data','service_product']   
x=x_cbow
y = aspect[categories]
        
x, y, x_train,x_test,y_train,y_test=splitdata_we(x,y,0.2,False)

xtrain_vect=x_train.astype('float32')
xtest_vect=x_test.astype('float32')
y_train=y_train.astype('float32')
y_test=y_test.astype('float32')

grid_values = {'estimator__max_depth': [5,6,7,8],
               'estimator__num_leaves': [5,6,7],
               'estimator__max_bin': [5,6,7,8],
               'estimator__min_data_in_leaf': [4,5,6,7],
               'estimator__colsample_bytree' : [0.1,0.2,0.3,0.5],
                'estimator__subsample' : [0.1,0.2],
              }

grid_values = {'estimator__max_depth': [5,6,7],
               'estimator__num_leaves': [5,6],
               'estimator__max_bin': [8,10,12],

              } 


#clf.get_params().keys()
clf=OneVsRestClassifier(lgb.LGBMClassifier(boosting_type='gbdt', class_weight='balanced',n_estimators=50))

grid_clf = GridSearchCV(clf,param_grid = grid_values, scoring = 'f1_micro', n_jobs=-1, verbose=10, cv=3)
grid_clf.fit(xtrain_vect, y_train)

print("Best estimator: ",grid_clf.best_estimator_)
print("Best Cross Validation Score: ",grid_clf.best_score_)

model = grid_clf.best_estimator_
print("Accuracy of Lightgbm  Model")
print("--------------------------------------------")
predictions,predictions_prob = pred(model,xtrain_vect)
accuracy(y_train,predictions)

model = grid_clf.best_estimator_
print("Accuracy of Lightgbm Model")
print("--------------------------------------------")
predictions,predictions_prob = pred(model,xtest_vect)
accuracy(y_test,predictions)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done  45 out of  54 | elapsed:   11.9s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  51 out of  54 | elapsed:   13.6s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:   14.1s finished
# Best estimator:  OneVsRestClassifier(estimator=LGBMClassifier(class_weight='balanced', max_bin=8,
#                                              max_depth=5, n_estimators=50,
#                                              num_leaves=6))
# Best Cross Validation Score:  0.7303884297429626
# ...

# %%
#Neural network baased method 

from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate

import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

def pred_neural(clf, feature_vector_valid):
    predictions_prob = clf.predict(feature_vector_valid)
    predictions_prob_ = predictions_prob >= 0.5
    predictions = predictions_prob_.astype(int)
    return predictions, predictions_prob    
    

def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))

#Model with all featurs with countvect, tfidf with all (1,1), (1,2) ngrams 

# Splitting the file
categories=['network','billing_price','package','customer_service','data','service_product']   
x, y, x_train,x_val,x_test,y_train,y_val, y_test=splitdata(aspect,'cleanAnswer',categories,0.2,True)

#Training 
count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtrain_vect_count= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtrain_vect_count12= count_vect.transform(x_train).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtrain_vect_count13= count_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf= tfidf_vect.transform(x_train).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtrain_vect_tfidf12= tfidf_vect.transform(x_train).astype('float32')

#Testing 

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xtest_vect_count= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xtest_vect_count12= count_vect.transform(x_test).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xtest_vect_count13= count_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf= tfidf_vect.transform(x_test).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xtest_vect_tfidf12= tfidf_vect.transform(x_test).astype('float32')


#validation

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,1))
count_vect.fit(x)
xval_vect_count= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,2))
count_vect.fit(x)
xval_vect_count12= count_vect.transform(x_val).astype('float32')

count_vect = CountVectorizer(analyzer='word', token_pattern=r'\w{1,}',ngram_range=(1,3))
count_vect.fit(x)
xval_vect_count13= count_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,1), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf= tfidf_vect.transform(x_val).astype('float32')

tfidf_vect = TfidfVectorizer(analyzer='word', token_pattern=r'\w{1,}', ngram_range=(1,2), max_features=4000)
tfidf_vect.fit(x)
xval_vect_tfidf12= tfidf_vect.transform(x_val).astype('float32')

xtrain_vect=scipy.sparse.hstack([xtrain_vect_count, xtrain_vect_tfidf,xtrain_vect_tfidf12,xtrain_vect_count12,xtrain_vect_count13])
xtrain_vect=xtrain_vect.toarray()
xval_vect=scipy.sparse.hstack([xval_vect_count, xval_vect_tfidf,xval_vect_tfidf12,xval_vect_count12,xval_vect_count13])
xval_vect=xval_vect.toarray()
xtest_vect=scipy.sparse.hstack([xtest_vect_count, xtest_vect_tfidf,xtest_vect_tfidf12,xtest_vect_count12,xtest_vect_count13])
xtest_vect=xtest_vect.toarray()
y_train=y_train.values.astype('float32')
y_val=y_val.values.astype('float32')
y_test=y_test.values.astype('float32')

# define the keras model
model = Sequential()
model.add(Dense(16,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.5))
#model.add(Dense(256,input_dim=xtrain_vect.shape[1], activation='relu'))
#model.add(Dropout(0.5))
#model.add(Dense(128,input_dim=xtrain_vect.shape[1], activation='relu'))
#model.add(Dropout(0.5))
#model.add(Dense(64,input_dim=xtrain_vect.shape[1], activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(16,input_dim=xtrain_vect.shape[1], activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(6, activation='sigmoid'))

from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m,recall_m])
mc = ModelCheckpoint('best_model.h5', monitor='val_f1_m', mode='max', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_f1_m', mode='max', verbose=1,patience= 10 )

history = model.fit(xtrain_vect, y_train,validation_data=(xval_vect, y_val),callbacks=[mc,es],
                      epochs=100,batch_size=32,shuffle=True)

#Load saved model 
dependencies = {
    'recall_m': recall_m,
    'f1_m':f1_m,
    'precision_m':precision_m
    
}

model = load_model('best_model.h5',custom_objects=dependencies)

print("Basic model evaluation: ")
loss_train,acc_train,f1_train,pre_train,rec_train = model.evaluate(xtrain_vect, y_train, verbose=0)
loss_val,acc_val,f1_val,pre_val,rec_val = model.evaluate(xval_vect, y_val, verbose=0)
loss_test,acc_test,f1_test,pre_test,rec_test = model.evaluate(xtest_vect, y_test, verbose=0)

print("Loss ")
print('Train: %.3f,val: %.3f, Test: %.3f' % (loss_train,loss_val,loss_test))
print("Accuracy Scores ")
print('Train: %.3f,val: %.3f, Test: %.3f' % (acc_train,acc_val,acc_test))
print("F1 scores")
print('Train: %.3f,val: %.3f, Test: %.3f' % (f1_train,f1_val,f1_test))
print("Precision scores")
print('Train: %.3f,val: %.3f, Test: %.3f' % (pre_train,pre_val,pre_test))
print("Recall scores")
print('Train: %.3f,val: %.3f, Test: %.3f' % (rec_train,rec_val,rec_test))

print("Accuracy of Neural Network Model")
print("--------------------------------------------")

print("\nTraining accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,xtrain_vect)
accuracy(y_train,predictions)

print("\nValidation accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,xval_vect)
accuracy(y_val,predictions)

print("\n Testing accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,xtest_vect)
accuracy(y_test,predictions)

print("Learning curves")
print("loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.title("Loss")
pyplot.legend()
pyplot.show()

print("Accuracy")
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='val')
pyplot.title("Accuracy")
pyplot.legend()
pyplot.show()

print("F1")
pyplot.plot(history.history['f1_m'], label='train')
pyplot.plot(history.history['val_f1_m'], label='val')
pyplot.title("F1")
pyplot.legend()
pyplot.show()

print("Precision")
pyplot.plot(history.history['precision_m'], label='train')
pyplot.plot(history.history['val_precision_m'], label='val')
pyplot.title("Precision")
pyplot.legend()
pyplot.show()

print("F1")
pyplot.plot(history.history['recall_m'], label='train')
pyplot.plot(history.history['val_recall_m'], label='val')
pyplot.title("Recall")
pyplot.legend()
pyplot.show()
# Out:
# Train on 1722 samples, validate on 431 samples
# Epoch 1/100
# 1722/1722 [==============================] - 3s 2ms/step - loss: 0.6443 - accuracy: 0.7017 - f1_m: 0.3487 - precision_m: 0.4363 - recall_m: 0.3025 - val_loss: 0.5977 - val_accuracy: 0.7742 - val_f1_m: 0.4131 - val_precision_m: 0.7231 - val_recall_m: 0.2920
#
# Epoch 00001: val_f1_m improved from -inf to 0.41307, saving model to best_model.h5
# Epoch 2/100
# 1722/1722 [==============================] - 3s 2ms/step - loss: 0.5354 - accuracy: 0.7752 - f1_m: 0.5163 - precision_m: 0.6007 - recall_m: 0.4561 - val_loss: 0.5346 - val_accuracy: 0.7985 - val_f1_m: 0.5191 - val_precision_m: 0.7557 - val_recall_m: 0.3978
#
# Epoch 00002: val_f1_m improved from 0.41307 to 0.51910, saving model to best_model.h5
# Epoch 3/100
# ...

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model

def pred_neural(clf, feature_vector_valid):
    predictions_prob = clf.predict(feature_vector_valid)
    predictions_prob_ = predictions_prob >= 0.5
    predictions = predictions_prob_.astype(int)
    return predictions, predictions_prob    
    

def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))

#Model with all featurs with countvect, tfidf with all (1,1), (1,2) ngrams 


categories=['network','billing_price','package','customer_service','data','service_product']   
x=x_cbow
y = aspect[categories]
        
x, y, x_train,x_val,x_test,y_train,y_val,y_test=splitdata_we(x,y,0.2,True)

xtrain_vect=x_train.astype('float32')
xval_vect=x_val.astype('float32')
xtest_vect=x_test.astype('float32')
y_train=y_train.astype('float32')
y_val=y_val.astype('float32')
y_test=y_test.astype('float32')



# define the keras model
model = Sequential()
model.add(Dense(512,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(16,input_dim=xtrain_vect.shape[1], activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(6, activation='sigmoid'))

from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m,recall_m])
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1,patience= 500 )

history = model.fit(xtrain_vect, y_train,validation_data=(xval_vect, y_val),callbacks=[mc,es],
                      epochs=5000,batch_size=32,shuffle=True)

#Load saved model 
dependencies = {
    'recall_m': recall_m,
    'f1_m':f1_m,
    'precision_m':precision_m
    
}

model = load_model('best_model.h5',custom_objects=dependencies)

print("Basic model evaluation: ")
loss_train,acc_train,f1_train,pre_train,rec_train = model.evaluate(xtrain_vect, y_train, verbose=0)
loss_val,acc_val,f1_val,pre_val,rec_val = model.evaluate(xval_vect, y_val, verbose=0)
loss_test,acc_test,f1_test,pre_test,rec_test = model.evaluate(xtest_vect, y_test, verbose=0)

print("Loss ")
print('Train: %.3f,val: %.3f, Test: %.3f' % (loss_train,loss_val,loss_test))
print("Accuracy Scores ")
print('Train: %.3f,val: %.3f, Test: %.3f' % (acc_train,acc_val,acc_test))
print("F1 scores")
print('Train: %.3f,val: %.3f, Test: %.3f' % (f1_train,f1_val,f1_test))
print("Precision scores")
print('Train: %.3f,val: %.3f, Test: %.3f' % (pre_train,pre_val,pre_test))
print("Recall scores")
print('Train: %.3f,val: %.3f, Test: %.3f' % (rec_train,rec_val,rec_test))

print("Accuracy of Neural Network Model")
print("--------------------------------------------")

print("\nTraining accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,xtrain_vect)
accuracy(y_train,predictions)

print("\nValidation accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,xval_vect)
accuracy(y_val,predictions)

print("\n Testing accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,xtest_vect)
accuracy(y_test,predictions)

print("Learning curves")
print("loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.title("Loss")
pyplot.legend()
pyplot.show()

print("Accuracy")
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='val')
pyplot.title("Accuracy")
pyplot.legend()
pyplot.show()

print("F1")
pyplot.plot(history.history['f1_m'], label='train')
pyplot.plot(history.history['val_f1_m'], label='val')
pyplot.title("F1")
pyplot.legend()
pyplot.show()

print("Precision")
pyplot.plot(history.history['precision_m'], label='train')
pyplot.plot(history.history['val_precision_m'], label='val')
pyplot.title("Precision")
pyplot.legend()
pyplot.show()

print("F1")
pyplot.plot(history.history['recall_m'], label='train')
pyplot.plot(history.history['val_recall_m'], label='val')
pyplot.title("Recall")
pyplot.legend()
pyplot.show()
# Out:
# Train on 1722 samples, validate on 431 samples
# Epoch 1/5000
# 1722/1722 [==============================] - 1s 555us/step - loss: 0.6220 - accuracy: 0.6645 - f1_m: 0.2512 - precision_m: 0.3624 - recall_m: 0.2253 - val_loss: 0.5447 - val_accuracy: 0.7359 - val_f1_m: 0.3819 - val_precision_m: 0.4906 - val_recall_m: 0.3133
#
# Epoch 00001: val_accuracy improved from -inf to 0.73589, saving model to best_model.h5
# Epoch 2/5000
# 1722/1722 [==============================] - 0s 262us/step - loss: 0.5762 - accuracy: 0.7167 - f1_m: 0.2211 - precision_m: 0.4269 - recall_m: 0.1529 - val_loss: 0.5511 - val_accuracy: 0.7378 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
#
# Epoch 00002: val_accuracy improved from 0.73589 to 0.73782, saving model to best_model.h5
# Epoch 3/5000
# ...

# %%
#Neural network model with word embedding layer into nrural network (Pre trained cbow word embedddings)

from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate
from keras.layers.convolutional import Conv1D
from keras.layers import GlobalMaxPooling1D


def pred_neural(clf, feature_vector_valid):
    predictions_prob = clf.predict(feature_vector_valid)
    predictions_prob_ = predictions_prob >= 0.5
    predictions = predictions_prob_.astype(int)
    return predictions, predictions_prob    
    

def accuracy(y_val,y_pred):
    print("Accuracy Score: ",metrics.accuracy_score(y_val,y_pred))
    #print("AUC Score: ",metrics.accuracy_score(y_val,y_pred))
    print("Precision: ", metrics.precision_score(y_val,y_pred,average='micro'))
    print("Recall: ", metrics.recall_score(y_val,y_pred,average='micro'))
    print("F1 score: ", metrics.f1_score(y_val,y_pred,average='micro'))
    
    print("\nClassification report")
    print("---------------------")
    target_names = ['network','billing_price','package','customer_service','data','service_product']
    print(metrics.classification_report(y_val, y_pred,target_names=target_names))
    
from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

categories=['network','billing_price','package','customer_service','data','service_product']   
x=aspect['cleanAnswer']
y = aspect[categories].values

x, y, x_train,x_test,y_train,y_test=splitdata_we(x,y,0.2,False)

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(x_train)

x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)

vocab_size = len(tokenizer.word_index) + 1

maxlen = 200

x_train = pad_sequences(x_train, padding='post', maxlen=maxlen)
x_test = pad_sequences(x_test, padding='post', maxlen=maxlen)


embeddings_dictionary = dict()

cbow_file = open('test_w2v_cbow.txt', encoding="utf8")

for line in cbow_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary[word] = vector_dimensions
cbow_file.close()

embedding_matrix = zeros((vocab_size, 300))
for word, index in tokenizer.word_index.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector
        
model = Sequential()
embedding_layer = Embedding(vocab_size, 300,weights=[embedding_matrix],
                            input_length=maxlen, trainable=False)
model.add(embedding_layer)
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(6, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',f1_m,precision_m,recall_m])
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience= 50 )

history = model.fit(x_train, y_train, batch_size=128, epochs=200, verbose=1, validation_split=0.2,callbacks=[mc,es],
                   class_weight='balanced')

print("Basic model evaluation: ")
loss_train,acc_train,f1_train,pre_train,rec_train = model.evaluate(x_train, y_train, verbose=0)
loss_test,acc_test,f1_test,pre_test,rec_test = model.evaluate(x_test, y_test, verbose=0)

print("Loss ")
print('Train: %.3f, Test: %.3f' % (loss_train,loss_test))
print("Accuracy Scores ")
print('Train: %.3f, Test: %.3f' % (acc_train,acc_test))
print("F1 scores")
print('Train: %.3f, Test: %.3f' % (f1_train,f1_test))
print("Precision scores")
print('Train: %.3f, Test: %.3f' % (pre_train,pre_test))
print("Recall scores")
print('Train: %.3f, Test: %.3f' % (rec_train,rec_test))

print("Accuracy of Neural Network Model")
print("--------------------------------------------")

print("\nTraining accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,x_train)
accuracy(y_train,predictions)

print("\n Testing accuracy")
print("--------------------------------------------")
predictions, predictions_prob  = pred_neural(model,x_test)
accuracy(y_test,predictions)

print("Learning curves")
print("loss")
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='val')
pyplot.title("Loss")
pyplot.legend()
pyplot.show()

print("Accuracy")
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='val')
pyplot.title("Accuracy")
pyplot.legend()
pyplot.show()

print("F1")
pyplot.plot(history.history['f1_m'], label='train')
pyplot.plot(history.history['val_f1_m'], label='val')
pyplot.title("F1")
pyplot.legend()
pyplot.show()

print("Precision")
pyplot.plot(history.history['precision_m'], label='train')
pyplot.plot(history.history['val_precision_m'], label='val')
pyplot.title("Precision")
pyplot.legend()
pyplot.show()

print("F1")
pyplot.plot(history.history['recall_m'], label='train')
pyplot.plot(history.history['val_recall_m'], label='val')
pyplot.title("Recall")
pyplot.legend()
pyplot.show()
# Out:
# Train on 1722 samples, validate on 431 samples
# Epoch 1/200
# 1722/1722 [==============================] - 7s 4ms/step - loss: 0.5498 - accuracy: 0.7256 - f1_m: 0.2468 - precision_m: 0.5054 - recall_m: 0.2184 - val_loss: 0.4913 - val_accuracy: 0.7761 - val_f1_m: 0.4718 - val_precision_m: 0.6224 - val_recall_m: 0.3806
#
# Epoch 00001: val_loss improved from inf to 0.49134, saving model to best_model.h5
# Epoch 2/200
# 1722/1722 [==============================] - 7s 4ms/step - loss: 0.4477 - accuracy: 0.8012 - f1_m: 0.4882 - precision_m: 0.7874 - recall_m: 0.3560 - val_loss: 0.4367 - val_accuracy: 0.8105 - val_f1_m: 0.5116 - val_precision_m: 0.7835 - val_recall_m: 0.3818
#
# Epoch 00002: val_loss improved from 0.49134 to 0.43666, saving model to best_model.h5
# Epoch 3/200
# ...

# %% [markdown]
# # Compare deep learing models
#
#
# ```
# # This is formatted as code
# ```

# %%
def getXY(df,x,y):
    x=df[x]
    y=df[y]
    return x,y

def encodeY(y,classes):
    encoder = preprocessing.LabelEncoder()
    y_c = encoder.fit_transform(y)
    y_c = label_binarize(y_c, classes=classes)
    return y_c

def emb_dictionary(filename):
    embedding_dictionary = dict()
    f = open(filename)
    for line in f:
        values = line.split()
        word = values[0]
        coefs = asarray(values[1:], dtype='float32')
        embedding_dictionary[word] = coefs
    f.close()
    return embedding_dictionary

def emb_matrix(vocab_length,word_tokenizer,embeddings_dictionary,we_size):
    embedding_matrix = zeros((vocab_length, we_size))
    for word, index in word_tokenizer.word_index.items():
        embedding_vector = embeddings_dictionary.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector
    return  embedding_matrix

def get_emb_sentences(X):
    word_tokenizer = Tokenizer()
    word_tokenizer.fit_on_texts(x)
    vocab_length = len(word_tokenizer.word_index) + 1
    embedded_sentences = word_tokenizer.texts_to_sequences(x)
    return word_tokenizer,embedded_sentences,vocab_length

def get_padded_sequence(x,embedded_sentences):
    word_count = lambda sentence: len(word_tokenize(sentence))
    longest_sentence = max(x, key=word_count)
    length_long_sentence = len(word_tokenize(longest_sentence))
    padded_sentences = pad_sequences(embedded_sentences, length_long_sentence, padding='post')
    return length_long_sentence,padded_sentences 

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


def train_model(model,x_train, y_train, cross_validation = False):
    print('Model Trainin and testing')
    es = EarlyStopping(monitor='val_f1_m', mode='max', verbose=1, patience=patience)
    mc = ModelCheckpoint(model_save_path, monitor='val_f1_m', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [es,mc]
    if(cross_validation):
        callbacks_list=[es]
    history = model.fit(x_train, y_train, validation_split=validation_split, epochs=epochs, batch_size=batch_size, 
                    callbacks=callbacks_list, verbose=1)
    return model,history

# %%
def loadembedding_matrix(x,loc,emb_size):
  word_tokenizer,embedded_sentences,vocab_length=get_emb_sentences(x)
  length_long_sentence,padded_sentences = get_padded_sequence(x,embedded_sentences)
  embeddings_dictionary=emb_dictionary(loc)
  embedding_matrix=emb_matrix(vocab_length,word_tokenizer,embeddings_dictionary,emb_size)
  return vocab_length,padded_sentences,length_long_sentence,embedding_matrix

def cnn_model():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix],input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Conv1D(256,3, activation='relu'))
    model.add(GlobalMaxPooling1D())
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Flatten())
    model.add(Dense(NUM_CLASSES, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model 

#GRU/LSTM/
def rnn_model():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(RNN(HIDDEN_DIMS))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model 

def simplernn_model():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(SimpleRNN(HIDDEN_DIMS))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model 


def stack_lstm2():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(LSTM(HIDDEN_DIMS,return_sequences=True))
    model.add(LSTM(HIDDEN_DIMS))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model 

def stack_lstm3():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(LSTM(HIDDEN_DIMS,return_sequences=True))
    model.add(LSTM(HIDDEN_DIMS,return_sequences=True))
    model.add(LSTM(HIDDEN_DIMS))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model

def bilstm():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(Bidirectional(LSTM(HIDDEN_DIMS)))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model

def stacked_bilstm2():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(Bidirectional(LSTM(HIDDEN_DIMS,return_sequences=True)))
    model.add(Bidirectional(LSTM(HIDDEN_DIMS)))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model

def stacked_bilstm3():
    model = Sequential()
    embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
    model.add(embedding_layer)
    model.add(Dropout(DROPOUT_VALUE_1))
    model.add(Bidirectional(LSTM(HIDDEN_DIMS,return_sequences=True)))
    model.add(Bidirectional(LSTM(HIDDEN_DIMS,return_sequences=True)))
    model.add(Bidirectional(LSTM(HIDDEN_DIMS)))
    model.add(Dense(HIDDEN_DIMS, activation='relu'))
    model.add(Dropout(DROPOUT_VALUE_2))
    model.add(Dense(NUM_CLASSES,activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
    return model

def cnn_rnn_model():
  model = Sequential()
  embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
  model.add(embedding_layer)
  model.add(Conv1D(filters=NB_FILTERS,kernel_size=KERNEL_SIZE, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(RNN(HIDDEN_DIMS,return_sequences=True))
  model.add(RNN(HIDDEN_DIMS))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Dense(NUM_CLASSES, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
  return model 

def cnn_bilstm_model():
  model = Sequential()
  embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
  model.add(embedding_layer)
  model.add(Conv1D(filters=NB_FILTERS,kernel_size=KERNEL_SIZE, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Bidirectional(LSTM(HIDDEN_DIMS)))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Dense(NUM_CLASSES, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
  return model 


def cnn_stackedbilstm2_model():
  model = Sequential()
  embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
  model.add(embedding_layer)
  model.add(Conv1D(filters=NB_FILTERS,kernel_size=KERNEL_SIZE, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Bidirectional(LSTM(HIDDEN_DIMS,return_sequences=True)))
  model.add(Bidirectional(LSTM(HIDDEN_DIMS)))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Dense(NUM_CLASSES, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
  return model 

def cnn_stackedbilstm3_model():
  model = Sequential()
  embedding_layer = Embedding(vocab_length,EMBEDDING_SIZE,weights=[embedding_matrix], input_length=length_long_sentence, trainable=False)
  model.add(embedding_layer)
  model.add(Conv1D(filters=NB_FILTERS,kernel_size=KERNEL_SIZE, padding='same', activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Bidirectional(LSTM(HIDDEN_DIMS,return_sequences=True)))
  model.add(Bidirectional(LSTM(HIDDEN_DIMS,return_sequences=True)))
  model.add(Bidirectional(LSTM(HIDDEN_DIMS)))
  model.add(Dropout(DROPOUT_VALUE_2))
  model.add(Dense(NUM_CLASSES, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy",precision_m,recall_m,f1_m])
  return model 

def crossval(model_name):

  # Define per-fold score containers <-- these are new
  acc_per_fold = []
  loss_per_fold = []
  f1_per_fold = []
  precision_per_fold =[]
  recall_per_fold=[]

  skf = StratifiedKFold(n_splits=N_FOLDS,random_state=None, shuffle=False)
  fold_no = 1
  for train_index, test_index in skf.split(padded_sentences,y):
    if model_name=='cnn':
      model=cnn_model()
    elif model_name=='rnn':
      model=rnn_model()
    elif model_name=='stacklstm2':
      model=stack_lstm2()
    elif model_name=='stacklstm3':
      model=stack_lstm3()
    elif model_name=='bilstm':
      model=bilstm()
    elif model_name=='stackbilstm2':
      model=stacked_bilstm2()
    elif model_name=='stackbilstm3':
      model=stacked_bilstm3()
    elif model_name=='cnnbilstm':
      model=cnn_bilstm_model()
    elif model_name=='cnnstackbilstm2':
      model=cnn_stackedbilstm2_model()
    elif model_name=='cnnstackbilstm3':
      model=cnn_stackedbilstm3_model()
    elif model_name=='simplernn':
      model=simplernn_model()
    else:
      model=cnn_rnn_model()

    es = EarlyStopping(monitor=MONITOR, mode=MONITOR_MODE, verbose=1,patience= PATIENCE )
    history = model.fit(padded_sentences[train_index],y_c[train_index],epochs=EPOCHS,callbacks=[es],batch_size=BATCH_SIZE,shuffle=SHUFFLE,validation_split=VALIDATION_SPLIT)
    
    # Generate generalization metrics
    scores = model.evaluate(padded_sentences[test_index], y_c[test_index], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}% ;{model.metrics_names[2]} of {scores[2]} ;{model.metrics_names[3]} of {scores[3]} ; \
           {model.metrics_names[4]} of {scores[4]}')
    loss_per_fold.append(scores[0])
    acc_per_fold.append(scores[1] * 100)
    precision_per_fold.append(scores[2])
    recall_per_fold.append(scores[3])
    f1_per_fold.append(scores[4])

    # Increase fold number
    fold_no = fold_no + 1

  acc=np.mean(acc_per_fold)
  precision=np.mean(precision_per_fold)
  recall=np.mean(recall_per_fold)
  f1=np.mean(f1_per_fold)
  loss=np.mean(loss_per_fold)
  return acc,precision,recall,f1,loss

# %%
MODELS_LIST=['cnn','rnn_gru','rnn_lstm','simplernn','stacklstm2','stacklstm3','bilstm','stackbilstm2','stackbilstm3','cnnbilstm','cnnstackbilstm2','cnnstackbilstm3','cnn_gru','cnn_lstm']
MODELS_LIST=['rnn_gru','rnn_lstm','simplernn','stacklstm2','stacklstm3']

N_FOLDS=3
EPOCHS=10
VALIDATION_SPLIT=0.2 
BATCH_SIZE=32 
PATIENCE=10
MONITOR='val_f1_m' 
MONITOR_MODE='max' 
shuffle=True 
DROPOUT_VALUE_2=0.5 
DROPOUT_VALUE_1=0.5 
NUM_CLASSES=6
NB_FILTERS=200 
KERNEL_SIZE=5
SHUFFLE=True
HIDDEN_DIMS=NB_FILTERS*2
L2_REG=0.1
EMBEDDING_SIZE=400
we_type='cbow'
activation='softmax'
loss='categorical_crossentropy'

x=df['cleanAnswer']
y=df['sentiment']
y_c=encodeY(y,[0,1,2])

acclist=[] ; prelist=[]  ; reclist=[]  ; f1list=[]  ; losslist=[] ; modelname=[] ; wename=[] ; wesize = []

for mod in MODELS_LIST:
  we_path=mainloc+'word_embeddings/w2v_'+we_type+'_'+str(EMBEDDING_SIZE)+'.txt'
  vocab_length,padded_sentences,length_long_sentence,embedding_matrix=loadembedding_matrix(x,we_path,EMBEDDING_SIZE)
  if (mod=='cnn'):
    acc,precision,recall,f1,loss=crossval(mod)
  elif (mod=='rnn_gru' or  mod=='rnn_lstm'):
    print(1)
    if (mod.split('_')[1]=='gru'):
      print(1.1)
      RNN=GRU
    else:
      print(1.2)
      RNN=LSTM
    acc,precision,recall,f1,loss=crossval('rnn')
  elif (mod=='stacklstm2'):
    print(3)
    acc,precision,recall,f1,loss=crossval('stacklstm2')
  elif (mod=='stacklstm3'):
    print(4)
    acc,precision,recall,f1,loss=crossval('stacklstm3')
  elif (mod=='bilstm'):
    acc,precision,recall,f1,loss=crossval('bilstm')
  elif (mod=='stackbilstm2'):
    acc,precision,recall,f1,loss=crossval('stackbilstm2')
  elif (mod=='stackbilstm3'):
    acc,precision,recall,f1,loss=crossval('stackbilstm3')
  elif (mod=='cnnbilstm'):
    acc,precision,recall,f1,loss=crossval('cnnbilstm')
  elif (mod=='cnnstackbilstm2'):
    acc,precision,recall,f1,loss=crossval('cnnstackbilstm2')
  elif (mod=='cnnstackbilstm3'):
    acc,precision,recall,f1,loss=crossval('cnnstackbilstm3')
  elif (mod=='simplernn'):
    print(2)
    acc,precision,recall,f1,loss=crossval('simplernn')
  else:
    print("issue")
    if (mod.split('_')[1]=='gru'):
      RNN=GRU
    else:
      RNN=LSTM
    acc,precision,recall,f1,loss=crossval('cnn_rnn')
    
  modelname.append(mod)
  wename.append(we_type)
  wesize.append(EMBEDDING_SIZE)
  acclist.append(acc)
  prelist.append(precision)
  reclist.append(recall)
  f1list.append(f1)
  losslist.append(loss)        
  
  accdf=pd.DataFrame({'Model':modelname,'Word_Embedding':wename, 'Embedding_Size':wesize,'Accuracy':acclist,'Precision':prelist,'Recall':reclist, 'F1':f1list})
  accdf.to_csv(mainloc+"Aspect_Accuracies.csv",index=False)

accdf=pd.DataFrame({'Model':modelname,'Word_Embedding':wename, 'Embedding_Size':wesize,'Accuracy':acclist,'Precision':prelist,'Recall':reclist, 'F1':f1list})
accdf.to_csv(mainloc+"Aspect_Accuracies.csv",index=False)
